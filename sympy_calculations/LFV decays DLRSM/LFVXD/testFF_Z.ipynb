# %%
from sympy import symbols, init_printing, Function
init_printing()

# %%
mX, ma, mb, M0, M1, M2 = symbols('m_X, m_a, m_b, M_0, M_1, M_2', positive=True)

# %% [markdown]
# # LFVHD H functions

# %% [markdown]
# ## FSS

# %%
from Zboson.functionsFSS import HFSS, IFSS

# %%
HFSS(mX, ma, mb, M0, M1, M2, 1)
# Out:
# M₀⋅(C₀(m_X, mₐ, m_b, M₀, M₁, M₂) - C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + C₂(m_X, mₐ,
# m_b, M₀, M₁, M₂))

# %%
HFSS(mX, ma, mb, M0, M1, M2, 1).doit()
# Out:
#    ⎛                                   2 ⎛  ⎛    2     2      2⎞
#    ⎜                               2⋅mₐ ⋅⎝- ⎝- M₀  + M₂  + m_b ⎠⋅C₀(m_X, mₐ, m
# M₀⋅⎜C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + ───────────────────────────────────────────
#    ⎜
#    ⎜
#    ⎝
#
#                                                        ⎞   ⎛     2     2
# _b, M₀, M₁, M₂) - B₁₂ ₀(m_X, M₁, M₂) + B₁ ₀(mₐ, M₀, M₁)⎠ + ⎝- m_X  + mₐ  + m_b
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                    2    2   ⎛     2     2
#                                                4⋅mₐ ⋅m_b  - ⎝- m_X  + mₐ  + m_
#
# 2⎞ ⎛⎛    2     2     2⎞
#  ⎠⋅⎝⎝- M₀  + M₁  + mₐ ⎠⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + B₁₂ ₀(m_X, M₁, M₂) - B₂
# ──────────────────────────────────────────────────────────────────────────────
#    2
#  2⎞
# b ⎠
#
#                ⎞        2 ⎛  ⎛    2     2     2⎞
#  ₀(m_b, M₀, M₂)⎠   2⋅m_b ⋅⎝- ⎝- M₀  + M₁  + mₐ ⎠⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)
# ...

# %%
HFSS(125, 1, 2, 3, 4, 5, 1)
# Out:
# -3⋅C₁(125, 1, 2, 3, 4, 5) + 3⋅C₂(125, 1, 2, 3, 4, 5) + 3⋅C₀(125, 1, 2, 3, 4, 5
# )

# %%
HFSS(125, 1, 2, 3, 4, 5, 1).evalf()
# Out:
# 0.0041394984059027 + 0.00449400197634598⋅ⅈ

# %%
HFSS(mX, ma, mb, M0, M1, M2, 2)
# Out:
# m_b⋅(C₁₂(m_X, mₐ, m_b, M₀, M₁, M₂) - C₂(m_X, mₐ, m_b, M₀, M₁, M₂) - C₂₂(m_X, m
# ₐ, m_b, M₀, M₁, M₂))

# %%
HFSS(mX, ma, mb, M0, M1, M2, 3)
# Out:
# mₐ⋅(C₁(m_X, mₐ, m_b, M₀, M₁, M₂) - C₁₁(m_X, mₐ, m_b, M₀, M₁, M₂) + C₁₂(m_X, mₐ
# , m_b, M₀, M₁, M₂))

# %%
IFSS(mX, ma, mb, M0, M1, M2, 3)
# Out:
# -C₀₀(m_X, mₐ, m_b, M₀, M₁, M₂)

# %% [markdown]
# ## FSV

# %%
from Zboson.functionsFSV import HFSV, IFSV

# %%
HFSV(mX, ma, mb, M0, M1, M2, 1)
# Out:
# -2⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)

# %%
for i in range(1,5):
    print(i)
    display(IFSV(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
# mₐ⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂)
# 2
# 0
# 3
# M₀⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)
# 4
# m_b⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)

# %% [markdown]
# ## FVS

# %%
from Zboson.functionsFVS import HFVS, IFVS

# %%
HFVS(mX, ma, mb, M0, M1, M2, 3)
# Out:
# 2⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂)

# %%
for i in range(1,5):
    print(i)
    display(IFVS(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
# M₀⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)
# 2
# -m_b⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)
# 3
# -mₐ⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂)
# 4
# 0

# %% [markdown]
# ## FVV

# %%
from Zboson.functionsFVV import HFVV, IFVV

# %%
for i in range(1,5):
    print(i)
    display(HFVV(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
# -2⋅mₐ⋅((2 - D)⋅(C₁₁(m_X, mₐ, m_b, M₀, M₁, M₂) - C₁₂(m_X, mₐ, m_b, M₀, M₁, M₂))
#  - (4 - D)⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + C₂(m_X, mₐ, m_b, M₀, M₁, M₂))
# 2
# 0
# 3
# 2⋅M₀⋅((1 - D)⋅(C₁(m_X, mₐ, m_b, M₀, M₁, M₂) - C₂(m_X, mₐ, m_b, M₀, M₁, M₂)) -
# (4 - D)⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂))
# 4
# 2⋅m_b⋅((2 - D)⋅(C₁₂(m_X, mₐ, m_b, M₀, M₁, M₂) - C₂₂(m_X, mₐ, m_b, M₀, M₁, M₂))
#  - (4 - D)⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂) + C₁(m_X, mₐ, m_b, M₀, M₁, M₂))

# %%
for i in range(1,5):
    print(i)
    display(IFVV(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
#   2                                                                        ⎛
# M₀ ⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) - (2 - D)⋅C₀₀(m_X, mₐ, m_b, M₀, M₁, M₂) + ⎝2⋅
#
#    2       2        2⎞                                ⎛     2       2        2
# m_X  - 3⋅mₐ  - 2⋅m_b ⎠⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) - ⎝2⋅m_X  - 2⋅mₐ  - 3⋅m_b
#
# ⎞
# ⎠⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂) + B₁₂ ₀(m_X, M₁, M₂)
# 2
# 3⋅M₀⋅m_b⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)
# 3
# 3⋅M₀⋅mₐ⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)
# 4
# 3⋅mₐ⋅m_b⋅(-C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + C₂(m_X, mₐ, m_b, M₀, M₁, M₂))

# %% [markdown]
# ## FS

# %%
from Zboson.functionsFS import IFS

# %%
for i in range(1,5):
    print(i)
    display(IFS(ma, mb, M0, M1, i))
# Out:
# 1
# -M₀⋅mₐ⋅B₁ ₀(mₐ, M₀, M₁)
# ────────────────────────
#          2      2
#        mₐ  - m_b
# 2
#    2
# -mₐ ⋅B₁ ₁(mₐ, M₀, M₁)
# ──────────────────────
#         2      2
#       mₐ  - m_b
# 3
# -mₐ⋅m_b⋅B₁ ₁(mₐ, M₀, M₁)
# ─────────────────────────
#           2      2
#         mₐ  - m_b
# 4
# -M₀⋅m_b⋅B₁ ₀(mₐ, M₀, M₁)
# ─────────────────────────
#           2      2
#         mₐ  - m_b

# %% [markdown]
# ## SF

# %%
from Zboson.functionsSF import ISF

# %%
for i in range(1,5):
    print(i)
    display(ISF(ma, mb, M0, M2, i))
# Out:
# 1
# -M₀⋅mₐ⋅B₂ ₀(m_b, M₀, M₂)
# ─────────────────────────
#            2      2
#        - mₐ  + m_b
# 2
#     2
# -m_b ⋅B₂ ₁(m_b, M₀, M₂)
# ────────────────────────
#           2      2
#       - mₐ  + m_b
# 3
# mₐ⋅m_b⋅B₂ ₁(m_b, M₀, M₂)
# ────────────────────────
#           2      2
#       - mₐ  + m_b
# 4
# M₀⋅m_b⋅B₂ ₀(m_b, M₀, M₂)
# ────────────────────────
#           2      2
#       - mₐ  + m_b

# %% [markdown]
# ## FV

# %%
from Zboson.functionsFV import IFV

# %%
for i in range(1,5):
    print(i)
    display(IFV(ma, mb, M0, M1, i))
# Out:
# 1
#   2
# mₐ ⋅(2 - D)⋅B₁ ₁(mₐ, M₀, M₁)
# ────────────────────────────
#            2      2
#          mₐ  - m_b
# 2
# D⋅M₀⋅mₐ⋅B₁ ₀(mₐ, M₀, M₁)
# ────────────────────────
#          2      2
#        mₐ  - m_b
# 3
# D⋅M₀⋅m_b⋅B₁ ₀(mₐ, M₀, M₁)
# ─────────────────────────
#           2      2
#         mₐ  - m_b
# 4
# mₐ⋅m_b⋅(2 - D)⋅B₁ ₁(mₐ, M₀, M₁)
# ───────────────────────────────
#              2      2
#            mₐ  - m_b

# %% [markdown]
# ## VF

# %%
from Zboson.functionsVF import IVF

# %%
for i in range(1,5):
    print(i)
    display(IVF(ma, mb, M0, M2, i))
# Out:
# 1
#    2
# m_b ⋅(D - 2)⋅B₂ ₁(m_b, M₀, M₂)
# ──────────────────────────────
#              2      2
#          - mₐ  + m_b
# 2
# D⋅M₀⋅mₐ⋅B₂ ₀(m_b, M₀, M₂)
# ─────────────────────────
#            2      2
#        - mₐ  + m_b
# 3
# D⋅M₀⋅m_b⋅B₂ ₀(m_b, M₀, M₂)
# ──────────────────────────
#            2      2
#        - mₐ  + m_b
# 4
# mₐ⋅m_b⋅(D - 2)⋅B₂ ₁(m_b, M₀, M₂)
# ────────────────────────────────
#               2      2
#           - mₐ  + m_b

# %% [markdown]
# ## SFF

# %%
from Zboson.functionsSFF import HSFF, ISFF

# %%
for i in range(1,9):
    print(i)
    display(HSFF(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
# 2⋅M₂⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)
# 2
# 0
# 3
# 2⋅m_b⋅(C₁₂(m_X, mₐ, m_b, M₀, M₁, M₂) + C₂(m_X, mₐ, m_b, M₀, M₁, M₂) - C₂₂(m_X,
#  mₐ, m_b, M₀, M₁, M₂))
# 4
# 0
# 5
# -2⋅M₁⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂)
# 6
# 2⋅mₐ⋅(2⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₁(m_X, mₐ, m_b, M₀, M₁, M₂) - C₁₁(m_X,
#  mₐ, m_b, M₀, M₁, M₂) + C₁₂(m_X, mₐ, m_b, M₀, M₁, M₂))
# 7
# 0
# 8
# 0

# %%
for i in range(1,9):
    print(i)
    display(ISFF(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
# M₂⋅mₐ⋅(-C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₁(m_X, mₐ, m_b, M₀, M₁, M₂))
# 2
# M₁⋅M₂⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)
# 3
# -mₐ⋅m_b⋅(-C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₁(m_X, mₐ, m_b, M₀, M₁, M₂) - C₂(m_X
# , mₐ, m_b, M₀, M₁, M₂))
# 4
# -M₁⋅m_b⋅(C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₂(m_X, mₐ, m_b, M₀, M₁, M₂))
# 5
# -M₁⋅mₐ⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂)
# 6
#     2                                  2                                   2
# - M₀ ⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + mₐ ⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) - m_b ⋅C
#
#
# ₂(m_X, mₐ, m_b, M₀, M₁, M₂) - B₁₂ ₀(m_X, M₁, M₂) + 2⋅C₀₀(m_X, mₐ, m_b, M₀, M₁,
#
#
#  M₂)
# 7
# 0
# 8
# M₂⋅m_b⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)

# %% [markdown]
# ## VFF

# %%
from Zboson.functionsVFF import HVFF, IVFF

# %%
for i in range(1,9):
    print(i)
    display(HVFF(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
# mₐ⋅(4 - 2⋅D)⋅(C₁₁(m_X, mₐ, m_b, M₀, M₁, M₂) - C₁₂(m_X, mₐ, m_b, M₀, M₁, M₂)) +
#  mₐ⋅(4 - 2⋅D)⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + 4⋅mₐ⋅(C₁(m_X, mₐ, m_b, M₀, M₁, M₂
# ) - C₂(m_X, mₐ, m_b, M₀, M₁, M₂)) - 4⋅mₐ⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + m_b⋅(8
#  - 2⋅D)⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)
# 2
# M₁⋅((2⋅D - 4)⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + 4⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) -
# 4⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂))
# 3
# 0
# 4
# 0
# 5
# 0
# 6
# M₁⋅((4 - 2⋅D)⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂) - 4⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) +
# 4⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂))
# 7
# 0
# 8
# m_b⋅(2⋅D - 4)⋅(C₁₂(m_X, mₐ, m_b, M₀, M₁, M₂) - C₂₂(m_X, mₐ, m_b, M₀, M₁, M₂))
# + 4⋅m_b⋅(-C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + C₂(m_X, mₐ, m_b, M₀, M₁, M₂))

# %%
for i in range(1,9):
    print(i)
    display(IVFF(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
#       2
# - 2⋅mₐ ⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + mₐ⋅m_b⋅(D - 4)⋅C₁(m_X, mₐ, m_b, M₀, M₁,
#
#             2                                        ⎛    2
#  M₂) - 2⋅m_b ⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂) + (2 - D)⋅⎝- M₀ ⋅C₀(m_X, mₐ, m_b, M
#
#                                                                  ⎞   ⎛     2
# ₀, M₁, M₂) - B₁₂ ₀(m_X, M₁, M₂) + 2⋅C₀₀(m_X, mₐ, m_b, M₀, M₁, M₂)⎠ - ⎝2⋅m_X  +
#
#    2        ⎞                                ⎛       2       2        2⎞
#  mₐ ⋅(2 - D)⎠⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + ⎝- 2⋅m_X  + 2⋅mₐ  + 2⋅m_b ⎠⋅C₀(m_
#
#                           ⎛     2       2        2⎞
# X, mₐ, m_b, M₀, M₁, M₂) - ⎝2⋅m_X  - 2⋅mₐ  - 2⋅m_b ⎠⋅C₂(m_X, mₐ, m_b, M₀, M₁, M
#
#
# ₂)
# 2
# M₁⋅(4 - D)⋅(mₐ⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + m_b⋅(C₀(m_X, mₐ, m_b, M₀, M₁, M₂
# ) + C₂(m_X, mₐ, m_b, M₀, M₁, M₂)))
# 3
# M₂⋅m_b⋅(D - 4)⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)
# 4
# 0
# 5
# M₁⋅M₂⋅(2 - D)⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)
# 6
# ...

# %%
from PaVe2 import C0, C1, C2, C00, C11, C12, C22

# %%
c0, c1, c2 = C0(mX, ma, mb, M0, M1, M2), C1(mX, ma, mb, M0, M1, M2), C2(mX, ma, mb, M0, M1, M2)
c00 = C00(mX, ma, mb, M0, M1, M2)
c11 = C11(mX, ma, mb, M0, M1, M2)
c12 = C12(mX, ma, mb, M0, M1, M2)
c22 = C22(mX, ma, mb, M0, M1, M2)

IVFF(mX, ma, mb, M0, M1, M2, 1).collect([c0, c1, c2])
# Out:
#         ⎛    2
# (2 - D)⋅⎝- M₀ ⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) - B₁₂ ₀(m_X, M₁, M₂) + 2⋅C₀₀(m_X,
#
#                     ⎞   ⎛       2       2⎞                                ⎛
# mₐ, m_b, M₀, M₁, M₂)⎠ + ⎝- 2⋅m_X  + 2⋅mₐ ⎠⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂) + ⎝- 2
#
#     2       2        2⎞                                ⎛       2     2
# ⋅m_X  + 2⋅mₐ  + 2⋅m_b ⎠⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + ⎝- 2⋅m_X  - mₐ ⋅(2 - D)
#
#        2                 ⎞
#  - 2⋅mₐ  + mₐ⋅m_b⋅(D - 4)⎠⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂)

# %%
IVFF(mX, ma, mb, M0, M1, M2, 8).expand().collect([c0, c1, c2])
# Out:
#     ⎛                                                ⎛     2 ⎛  ⎛    2     2
#     ⎜                                           2⋅mₐ⋅⎝2⋅m_b ⋅⎝- ⎝- M₀  + M₁  +
# m_b⋅⎜-mₐ⋅(D - 2)⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + ──────────────────────────────
#     ⎜
#     ⎜
#     ⎝
#
#    2⎞                                                                      ⎞
#  mₐ ⎠⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) - B₁₂ ₀(m_X, M₁, M₂) + B₂ ₀(m_b, M₀, M₂)⎠ +
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                     2    2   ⎛
#                                                                 4⋅mₐ ⋅m_b  - ⎝
#
#  ⎛     2     2      2⎞ ⎛⎛    2     2      2⎞
#  ⎝- m_X  + mₐ  + m_b ⎠⋅⎝⎝- M₀  + M₂  + m_b ⎠⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + B₁
# ──────────────────────────────────────────────────────────────────────────────
#                     2
#      2     2      2⎞
# - m_X  + mₐ  + m_b ⎠
#
# ...
