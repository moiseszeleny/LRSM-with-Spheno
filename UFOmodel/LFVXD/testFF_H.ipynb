# %%
from sympy import symbols, init_printing
init_printing()

# %%
mX, ma, mb, M0, M1, M2 = symbols('m_X, m_a, m_b, M_0, M_1, M_2', positive=True)

# %% [markdown]
# # LFVHD H functions

# %% [markdown]
# ## FSS

# %%
from Higgs.functionsFSS import GFSS

# %%
GFSS(mX, ma, mb, M0, M1, M2, 1)
# Out:
# M₀⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)

# %%
GFSS(mX, ma, mb, M0, M1, M2, 1).doit()
# Out:
# M₀⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)

# %%
GFSS(125, 1, 2, 3, 4, 5, 1)
# Out:
# 3⋅C₀(125, 1, 2, 3, 4, 5)

# %%
GFSS(125, 1, 2, 3, 4, 5, 1).evalf()
# Out:
# 0.00400837827663103 + 0.00449768965552704⋅ⅈ

# %%
GFSS(mX, ma, mb, M0, M1, M2, 2)
# Out:
# -m_b⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)

# %%
GFSS(mX, ma, mb, M0, M1, M2, 2).doit()
# Out:
#      ⎛    2 ⎛  ⎛    2     2      2⎞
# -m_b⋅⎝2⋅mₐ ⋅⎝- ⎝- M₀  + M₂  + m_b ⎠⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) - B₁₂ ₀(m_X,
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                           ⎞   ⎛     2     2      2⎞ ⎛⎛    2     2     2⎞
# M₁, M₂) + B₁ ₀(mₐ, M₀, M₁)⎠ + ⎝- m_X  + mₐ  + m_b ⎠⋅⎝⎝- M₀  + M₁  + mₐ ⎠⋅C₀(m_
# ──────────────────────────────────────────────────────────────────────────────
#                                                   2
#                     2    2   ⎛     2     2      2⎞
#                 4⋅mₐ ⋅m_b  - ⎝- m_X  + mₐ  + m_b ⎠
#
#                                                                 ⎞⎞
# X, mₐ, m_b, M₀, M₁, M₂) + B₁₂ ₀(m_X, M₁, M₂) - B₂ ₀(m_b, M₀, M₂)⎠⎠
# ───────────────────────────────────────────────────────────────────

# %%
GFSS(125, 1, 2, 3, 4, 5, 2).evalf()
# Out:
# -4.63029700871081e-5 - 0.000404072033357978⋅ⅈ

# %% [markdown]
# ## FSV

# %%
from Higgs.functionsFSV import GFSV

# %%
for i in range(1,5):
    print(i)
    display(GFSV(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
#   2                                   2
# M₀ ⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + m_b ⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂) + B₁₂ ₀(m
#
#
# _X, M₁, M₂)
# 2
# -M₀⋅m_b⋅(C₀(m_X, mₐ, m_b, M₀, M₁, M₂) - C₂(m_X, mₐ, m_b, M₀, M₁, M₂))
# 3
# M₀⋅mₐ⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂)
# 4
# -mₐ⋅m_b⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂)

# %% [markdown]
# ## FVS

# %%
from Higgs.functionsFVS import GFVS

# %%
for i in range(1,5):
    print(i)
    display(GFVS(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
# M₀⋅mₐ⋅(C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₁(m_X, mₐ, m_b, M₀, M₁, M₂))
# 2
# mₐ⋅m_b⋅(C₁(m_X, mₐ, m_b, M₀, M₁, M₂) - C₂(m_X, mₐ, m_b, M₀, M₁, M₂))
# 3
#   2                                   2                                ⎛   2
# M₀ ⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + m_b ⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂) + ⎝m_X  -
#
#     2⎞
#  m_b ⎠⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + B₁₂ ₀(m_X, M₁, M₂)
# 4
# -M₀⋅m_b⋅(C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₂(m_X, mₐ, m_b, M₀, M₁, M₂))

# %% [markdown]
# ## FVV

# %%
from Higgs.functionsFVV import GFVV

# %%
for i in range(1,5):
    print(i)
    display(GFVV(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
# mₐ⋅(D - 2)⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂)
# 2
# 0
# 3
# -D⋅M₀⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)
# 4
# m_b⋅(2 - D)⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)

# %% [markdown]
# ## FS

# %%
from Higgs.functionsFS import GFS

# %%
for i in range(1,5):
    print(i)
    display(GFS(ma, mb, M0, M1, i))
# Out:
# 1
# -M₀⋅m_b⋅B₁ ₀(mₐ, M₀, M₁)
# ─────────────────────────
#           2      2
#         mₐ  - m_b
# 2
# -mₐ⋅m_b⋅B₁ ₁(mₐ, M₀, M₁)
# ─────────────────────────
#           2      2
#         mₐ  - m_b
# 3
#    2
# -mₐ ⋅B₁ ₁(mₐ, M₀, M₁)
# ──────────────────────
#         2      2
#       mₐ  - m_b
# 4
# -M₀⋅mₐ⋅B₁ ₀(mₐ, M₀, M₁)
# ────────────────────────
#          2      2
#        mₐ  - m_b

# %% [markdown]
# ## SF

# %%
from Higgs.functionsSF import GSF

# %%
for i in range(1,5):
    print(i)
    display(GSF(ma, mb, M0, M2, i))
# Out:
# 1
# -M₀⋅mₐ⋅B₂ ₀(m_b, M₀, M₂)
# ─────────────────────────
#            2      2
#        - mₐ  + m_b
# 2
#    2
# m_b ⋅B₂ ₁(m_b, M₀, M₂)
# ──────────────────────
#          2      2
#      - mₐ  + m_b
# 3
# mₐ⋅m_b⋅B₂ ₁(m_b, M₀, M₂)
# ────────────────────────
#           2      2
#       - mₐ  + m_b
# 4
# -M₀⋅m_b⋅B₂ ₀(m_b, M₀, M₂)
# ──────────────────────────
#            2      2
#        - mₐ  + m_b

# %% [markdown]
# ## FV

# %%
from Higgs.functionsFV import GFV

# %%
for i in range(1,5):
    print(i)
    display(GFV(ma, mb, M0, M1, i))
# Out:
# 1
# mₐ⋅m_b⋅(2 - D)⋅B₁ ₁(mₐ, M₀, M₁)
# ───────────────────────────────
#              2      2
#            mₐ  - m_b
# 2
# D⋅M₀⋅m_b⋅B₁ ₀(mₐ, M₀, M₁)
# ─────────────────────────
#           2      2
#         mₐ  - m_b
# 3
# D⋅M₀⋅mₐ⋅B₁ ₀(mₐ, M₀, M₁)
# ────────────────────────
#          2      2
#        mₐ  - m_b
# 4
#   2
# mₐ ⋅(2 - D)⋅B₁ ₁(mₐ, M₀, M₁)
# ────────────────────────────
#            2      2
#          mₐ  - m_b

# %% [markdown]
# ## VF

# %%
from Higgs.functionsVF import GVF

# %%
for i in range(1,5):
    print(i)
    display(GVF(ma, mb, M0, M2, i))
# Out:
# 1
#    2
# m_b ⋅(D - 2)⋅B₂ ₁(m_b, M₀, M₂)
# ──────────────────────────────
#              2      2
#          - mₐ  + m_b
# 2
# D⋅M₀⋅mₐ⋅B₂ ₀(m_b, M₀, M₂)
# ─────────────────────────
#            2      2
#        - mₐ  + m_b
# 3
# D⋅M₀⋅m_b⋅B₂ ₀(m_b, M₀, M₂)
# ──────────────────────────
#            2      2
#        - mₐ  + m_b
# 4
# mₐ⋅m_b⋅(D - 2)⋅B₂ ₁(m_b, M₀, M₂)
# ────────────────────────────────
#               2      2
#           - mₐ  + m_b

# %% [markdown]
# ## SFF

# %%
from Higgs.functionsSFF import GSFF

# %%
for i in range(1,9):
    print(i)
    display(GSFF(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
# M₁⋅M₂⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)
# 2
# M₂⋅mₐ⋅(-C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₁(m_X, mₐ, m_b, M₀, M₁, M₂))
# 3
# -M₁⋅m_b⋅(C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₂(m_X, mₐ, m_b, M₀, M₁, M₂))
# 4
# -mₐ⋅m_b⋅(-C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₁(m_X, mₐ, m_b, M₀, M₁, M₂) - C₂(m_X
# , mₐ, m_b, M₀, M₁, M₂))
# 5
#   2                                  2                                   2
# M₀ ⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) - mₐ ⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) - m_b ⋅C₂(
#
#
# m_X, mₐ, m_b, M₀, M₁, M₂) + B₁₂ ₀(m_X, M₁, M₂)
# 6
# M₁⋅mₐ⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂)
# 7
# -M₂⋅m_b⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)
# 8
# 0

# %% [markdown]
# ## VFF

# %%
from Higgs.functionsVFF import GVFF

# %%
for i in range(1,9):
    print(i)
    display(GVFF(mX, ma, mb, M0, M1, M2, i))
# Out:
# 1
# M₁⋅mₐ⋅(2 - D)⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂)
# 2
#   ⎛  2                                  2                                   2
# D⋅⎝M₀ ⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂) - mₐ ⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + m_b ⋅
#
#                                                  ⎞   ⎛     2       2        2⎞
# C₂(m_X, mₐ, m_b, M₀, M₁, M₂) + B₁₂ ₀(m_X, M₁, M₂)⎠ + ⎝2⋅m_X  - 2⋅mₐ  - 2⋅m_b ⎠
#
#
# ⋅(-C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₁(m_X, mₐ, m_b, M₀, M₁, M₂) - C₂(m_X, mₐ, m
#
#
# _b, M₀, M₁, M₂))
# 3
# 0
# 4
# M₂⋅m_b⋅(D - 2)⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)
# 5
# M₂⋅mₐ⋅(2 - D)⋅(-C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₁(m_X, mₐ, m_b, M₀, M₁, M₂))
# 6
# D⋅M₁⋅M₂⋅C₀(m_X, mₐ, m_b, M₀, M₁, M₂)
# 7
# mₐ⋅m_b⋅(4 - D)⋅(-C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₁(m_X, mₐ, m_b, M₀, M₁, M₂) -
#  C₂(m_X, mₐ, m_b, M₀, M₁, M₂))
# 8
# M₁⋅m_b⋅(D - 2)⋅(C₀(m_X, mₐ, m_b, M₀, M₁, M₂) + C₂(m_X, mₐ, m_b, M₀, M₁, M₂))

# %%
from PaVe2 import C0, C1, C2, D

# %%
c0 = C0(mX, ma, mb, M0, M1, M2)
c1 = C1(mX, ma, mb, M0, M1, M2)
c2 = C2(mX, ma, mb, M0, M1, M2)
GVFF(mX, ma, mb, M0, M1, M2, 2).expand().collect([c0, c1, c2])
# Out:
#                        ⎛    2        2       2        2⎞
# D⋅B₁₂ ₀(m_X, M₁, M₂) + ⎝D⋅M₀  - 2⋅m_X  + 2⋅mₐ  + 2⋅m_b ⎠⋅C₀(m_X, mₐ, m_b, M₀,
#
#           ⎛      2        2       2        2⎞                                ⎛
# M₁, M₂) + ⎝- D⋅mₐ  + 2⋅m_X  - 2⋅mₐ  - 2⋅m_b ⎠⋅C₁(m_X, mₐ, m_b, M₀, M₁, M₂) + ⎝
#
#      2        2       2        2⎞
# D⋅m_b  - 2⋅m_X  + 2⋅mₐ  + 2⋅m_b ⎠⋅C₂(m_X, mₐ, m_b, M₀, M₁, M₂)
