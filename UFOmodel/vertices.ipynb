# %% [markdown]
# In this notebook we investigate the vertexes needed to LFVZD in the MLRSM using the UFO model of [Roitgrund2016](https://www.sciencedirect.com/science/article/pii/S0010465515004476?via%3Dihub)

# %%
from UFOexplorerSympy import UFOModelExplorer

# %%
import MLRSM_UFO as model
import ufo_tools as tools
from sympy import sympify, init_printing
#init_printing()

parameters = model.parameters
particles = model.particles
couplings = model.couplings
vertices = model.vertices
L = model.lorentz


print(len(L.all_lorentz))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspaces/LRSM-with-Spheno/UFOmodel/vertices.ipynb Celda 3 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bjubilant-invention-w9v6vpvqwv6h94rv/workspaces/LRSM-with-Spheno/UFOmodel/vertices.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import MLRSM_UFO as model
#       <a href='vscode-notebook-cell://codespaces%2Bjubilant-invention-w9v6vpvqwv6h94rv/workspaces/LRSM-with-Spheno/UFOmodel/vertices.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import ufo_tools as tools
#       <a href='vscode-notebook-cell://codespaces%2Bjubilant-invention-w9v6vpvqwv6h94rv/workspaces/LRSM-with-Spheno/UFOmodel/vertices.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> from sympy import sympify, init_printing
#
# File /workspaces/LRSM-with-Spheno/UFOmodel/MLRSM_UFO/__init__.py:2
# ----> 2 import particles
#       3 import couplings
#       4 import lorentz
#
# ModuleNotFoundError: No module named 'particles'

# %%
all_lorentz = list({obj.name: obj for obj in L.all_lorentz}.values())

# %%
len(vertices.V_1.particles)
# Out:
# 4

# %%
'5'+'6'
# Out:
# '56'

# %%
len(all_lorentz)
# Out:
# 23

# %% [markdown]
# Print some vertices of the model

# %%
print(vertices.V_1.nice_string())
# Out:
# name 	: V_1
# particles 	: [A02, A02, A02, A02]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_46}

# %%
tools.create_dict_values(parameters.sw2, parameters.s12)
# Out:
# {s12: 0.221}

# %%
print(particles.all_particles)
# Out:
# [a, Z, W__plus__, W__minus__, g, W2__plus__, W2__minus__, Z2, ghG, ghG__tilde__, e__minus__, e__plus__, mu__minus__, mu__plus__, ta__minus__, ta__plus__, u, u__tilde__, c, c__tilde__, t, t__tilde__, d, d__tilde__, s, s__tilde__, b, b__tilde__, N1, N2, N3, N4, N5, N6, H, H01, H02, H03, G01, G02, GL__plus__, GL__minus__, GR__plus__, GR__minus__, HP1, HM1, HP2, HM2, HL__plus____plus__, HL__minus____minus__, HR__plus____plus__, HR__minus____minus__, A01, A02, a, Z, W__plus__, W__minus__, g, W2__plus__, W2__minus__, Z2, ghG, ghG__tilde__, e__minus__, e__plus__, mu__minus__, mu__plus__, ta__minus__, ta__plus__, u, u__tilde__, c, c__tilde__, t, t__tilde__, d, d__tilde__, s, s__tilde__, b, b__tilde__, N1, N2, N3, N4, N5, N6, H, H01, H02, H03, G01, G02, GL__plus__, GL__minus__, GR__plus__, GR__minus__, HP1, HM1, HP2, HM2, HL__plus____plus__, HL__minus____minus__, HR__plus____plus__, HR__minus____minus__, A01, A02]

# %% [markdown]
# # H interactions

# %%
vertices_H = [
    vertex for vertex in vertices.all_vertices if particles.H in vertex.particles
]
print(len(vertices_H), 'vertices with H')
# Out:
# 328 vertices with H

# %%
for vertex in vertices_H:
    print(vertex.nice_string())
# Out:
# name 	: V_69
# particles 	: [A01, A01, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_296}
# name 	: V_70
# particles 	: [G01, G01, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_300}
# name 	: V_71
# particles 	: [GL__minus__, GL__plus__, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_300}
# name 	: V_72
# particles 	: [H, H, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_304}
# name 	: V_76
# particles 	: [H, H, H01, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_298}
# name 	: V_81
# particles 	: [H, H, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_291}
# name 	: V_84
# particles 	: [A01, G01, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_292}
# name 	: V_86
# particles 	: [A01, GL__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_299}
# name 	: V_88
# particles 	: [GL__plus__, H, H01, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_295}
# name 	: V_91
# particles 	: [A01, GL__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_294}
# name 	: V_93
# particles 	: [GL__minus__, H, H01, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_295}
# name 	: V_98
# particles 	: [A01, G01, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_309}
# name 	: V_99
# particles 	: [A01, A01, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_308}
# name 	: V_100
# particles 	: [G01, G01, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_309}
# name 	: V_101
# particles 	: [GL__minus__, GL__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_309}
# name 	: V_102
# particles 	: [H, H, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_313}
# name 	: V_104
# particles 	: [H, H01, H01, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_312}
# name 	: V_108
# particles 	: [GL__plus__, H, H, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_306}
# name 	: V_113
# particles 	: [GL__minus__, H, H, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_306}
# name 	: V_116
# particles 	: [H, H01, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_308}
# name 	: V_119
# particles 	: [A01, A01, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_318}
# name 	: V_120
# particles 	: [G01, G01, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_321}
# name 	: V_121
# particles 	: [GL__minus__, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_321}
# name 	: V_122
# particles 	: [H, H, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_322}
# name 	: V_123
# particles 	: [H, H01, H01]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_319}
# name 	: V_124
# particles 	: [H, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_314}
# name 	: V_130
# particles 	: [A01, G01, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_325}
# name 	: V_134
# particles 	: [H, H, H01]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_327}
# name 	: V_136
# particles 	: [GL__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_323}
# name 	: V_137
# particles 	: [GL__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_323}
# name 	: V_153
# particles 	: [G02, GL__plus__, GR__minus__, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_345}
# name 	: V_154
# particles 	: [G02, GL__minus__, GR__plus__, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_343}
# name 	: V_155
# particles 	: [A02, A02, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_340}
# name 	: V_156
# particles 	: [G02, G02, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_340}
# name 	: V_157
# particles 	: [GR__minus__, GR__plus__, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_338}
# name 	: V_158
# particles 	: [A02, A02, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_334}
# name 	: V_159
# particles 	: [G02, G02, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_334}
# name 	: V_160
# particles 	: [GR__minus__, GR__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_333}
# name 	: V_166
# particles 	: [GL__plus__, GR__minus__, H, H02]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_344}
# name 	: V_167
# particles 	: [GL__minus__, GR__plus__, H, H02]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_344}
# name 	: V_172
# particles 	: [H, H, H02, H02]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_340}
# name 	: V_173
# particles 	: [H, H01, H02, H02]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_334}
# name 	: V_179
# particles 	: [H, H, H03, H03]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_340}
# name 	: V_180
# particles 	: [H, H01, H03, H03]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_334}
# name 	: V_183
# particles 	: [A02, GL__plus__, H, HM1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_345}
# name 	: V_185
# particles 	: [GL__plus__, H, H03, HM1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_344}
# name 	: V_187
# particles 	: [A02, GL__minus__, H, HP1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_343}
# name 	: V_189
# particles 	: [GL__minus__, H, H03, HP1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_344}
# name 	: V_194
# particles 	: [H, H, HM1, HP1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_338}
# name 	: V_195
# particles 	: [H, H01, HM1, HP1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_333}
# name 	: V_232
# particles 	: [GL__plus__, H, HP1, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_337}
# name 	: V_236
# particles 	: [GL__minus__, H, HM1, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_337}
# name 	: V_243
# particles 	: [H, H, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_328}
# name 	: V_244
# particles 	: [H, H01, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_335}
# name 	: V_250
# particles 	: [GL__plus__, GR__plus__, H, HR__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_337}
# name 	: V_254
# particles 	: [GL__minus__, GR__minus__, H, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_337}
# name 	: V_261
# particles 	: [H, H, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_328}
# name 	: V_262
# particles 	: [H, H01, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_335}
# name 	: V_284
# particles 	: [G02, GR__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_778}
# name 	: V_286
# particles 	: [GR__plus__, H, H02, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_776}
# name 	: V_288
# particles 	: [A02, H, HP1, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_778}
# name 	: V_290
# particles 	: [H, H03, HP1, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_776}
# name 	: V_292
# particles 	: [G02, GR__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_775}
# name 	: V_294
# particles 	: [GR__minus__, H, H02, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_776}
# name 	: V_296
# particles 	: [A02, H, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_775}
# name 	: V_298
# particles 	: [H, H03, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_776}
# name 	: V_302
# particles 	: [H, HP1, HP2, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_773}
# name 	: V_306
# particles 	: [H, HM1, HM2, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_773}
# name 	: V_310
# particles 	: [GR__plus__, H, HP2, HR__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_773}
# name 	: V_314
# particles 	: [GR__minus__, H, HM2, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_773}
# name 	: V_317
# particles 	: [A02, A02, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_466}
# name 	: V_318
# particles 	: [G02, G02, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_466}
# name 	: V_319
# particles 	: [GR__minus__, GR__plus__, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_465}
# name 	: V_325
# particles 	: [H, H02, H02]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_466}
# name 	: V_327
# particles 	: [H, H03, H03]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_466}
# name 	: V_333
# particles 	: [H, HM1, HP1]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_465}
# name 	: V_337
# particles 	: [H, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_460}
# name 	: V_341
# particles 	: [H, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_460}
# name 	: V_375
# particles 	: [H, H, H03]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_820}
# name 	: V_376
# particles 	: [H, H01, H03]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_819}
# name 	: V_379
# particles 	: [GL__plus__, H, HM1]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_823}
# name 	: V_381
# particles 	: [GL__minus__, H, HP1]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_823}
# name 	: V_394
# particles 	: [H, HP1, HM2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_800}
# name 	: V_396
# particles 	: [H, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_800}
# name 	: V_415
# particles 	: [GL__plus__, GR__minus__, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_971}
# name 	: V_416
# particles 	: [GL__minus__, GR__plus__, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_971}
# name 	: V_421
# particles 	: [H, H, H02]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_968}
# name 	: V_422
# particles 	: [H, H01, H02]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_967}
# name 	: V_436
# particles 	: [GR__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_948}
# name 	: V_438
# particles 	: [GR__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_948}
# name 	: V_501
# particles 	: [d__tilde__, d, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_975}
# name 	: V_502
# particles 	: [s__tilde__, s, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_979}
# name 	: V_503
# particles 	: [b__tilde__, b, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_983}
# name 	: V_507
# particles 	: [u__tilde__, u, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_1000}
# name 	: V_508
# particles 	: [c__tilde__, c, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_1004}
# name 	: V_509
# particles 	: [t__tilde__, t, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_1008}
# name 	: V_555
# particles 	: [N1, N1, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_675, (0, 1): GC_694}
# name 	: V_556
# particles 	: [N4, N1, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_681, (0, 1): GC_700}
# name 	: V_557
# particles 	: [N2, N2, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_677, (0, 1): GC_696}
# name 	: V_558
# particles 	: [N5, N2, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_685, (0, 1): GC_704}
# name 	: V_559
# particles 	: [N3, N3, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_679, (0, 1): GC_698}
# name 	: V_560
# particles 	: [N6, N3, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_689, (0, 1): GC_708}
# name 	: V_561
# particles 	: [N4, N4, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_683, (0, 1): GC_702}
# name 	: V_562
# particles 	: [N5, N5, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_687, (0, 1): GC_706}
# name 	: V_563
# particles 	: [N6, N6, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_691, (0, 1): GC_710}
# name 	: V_615
# particles 	: [e__plus__, e__minus__, H]
# color 	: ['1']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_987}
# name 	: V_616
# particles 	: [mu__plus__, mu__minus__, H]
# color 	: ['1']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_991}
# name 	: V_617
# particles 	: [ta__plus__, ta__minus__, H]
# color 	: ['1']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_995}
# name 	: V_679
# particles 	: [a, W__minus__, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_420}
# name 	: V_685
# particles 	: [a, W__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_428}
# name 	: V_696
# particles 	: [W__minus__, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_378}
# name 	: V_700
# particles 	: [W__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_395}
# name 	: V_723
# particles 	: [a, W2__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_361}
# name 	: V_725
# particles 	: [a, W2__minus__, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_427}
# name 	: V_739
# particles 	: [W2__minus__, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_393}
# name 	: V_742
# particles 	: [W2__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_347}
# name 	: V_774
# particles 	: [a, W2__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_361}
# name 	: V_776
# particles 	: [a, W2__plus__, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_427}
# name 	: V_790
# particles 	: [W2__plus__, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_396}
# name 	: V_793
# particles 	: [W2__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_348}
# name 	: V_806
# particles 	: [W__minus__, W2__plus__, A01, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_452}
# name 	: V_808
# particles 	: [W__minus__, W2__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_453}
# name 	: V_811
# particles 	: [W__minus__, W2__plus__, G01, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_451}
# name 	: V_812
# particles 	: [W__minus__, W2__plus__, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_448}
# name 	: V_818
# particles 	: [W__minus__, W2__plus__, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_764}
# name 	: V_834
# particles 	: [W2__minus__, W2__plus__, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_456}
# name 	: V_838
# particles 	: [W2__minus__, W2__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_405}
# name 	: V_839
# particles 	: [W2__minus__, W2__plus__, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_768}
# name 	: V_865
# particles 	: [a, W__plus__, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_420}
# name 	: V_871
# particles 	: [a, W__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_428}
# name 	: V_882
# particles 	: [W__plus__, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_381}
# name 	: V_886
# particles 	: [W__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_394}
# name 	: V_901
# particles 	: [W__minus__, W__plus__, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_457}
# name 	: V_905
# particles 	: [W__minus__, W__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_404}
# name 	: V_906
# particles 	: [W__minus__, W__plus__, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_769}
# name 	: V_922
# particles 	: [W2__minus__, W__plus__, A01, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_459}
# name 	: V_924
# particles 	: [W2__minus__, W__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_453}
# name 	: V_927
# particles 	: [W2__minus__, W__plus__, G01, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_446}
# name 	: V_928
# particles 	: [W2__minus__, W__plus__, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_448}
# name 	: V_934
# particles 	: [W2__minus__, W__plus__, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_764}
# name 	: V_995
# particles 	: [Z, G01, H]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_368}
# name 	: V_1010
# particles 	: [W__minus__, Z, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_387}
# name 	: V_1016
# particles 	: [W__minus__, Z, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_401}
# name 	: V_1030
# particles 	: [W2__minus__, Z, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_352}
# name 	: V_1032
# particles 	: [W2__minus__, Z, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_443}
# name 	: V_1048
# particles 	: [W2__plus__, Z, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_352}
# name 	: V_1050
# particles 	: [W2__plus__, Z, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_443}
# name 	: V_1066
# particles 	: [W__plus__, Z, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_387}
# name 	: V_1072
# particles 	: [W__plus__, Z, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_401}
# name 	: V_1090
# particles 	: [Z, Z, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_375}
# name 	: V_1093
# particles 	: [Z, Z, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_750}
# name 	: V_1114
# particles 	: [Z2, G01, H]
# color 	: ['1']
# lorentz 	: [VSS1, VSS3]
# couplings 	: {(0, 0): GC_367, (0, 1): GC_364}
# name 	: V_1129
# particles 	: [W__minus__, Z2, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_410}
# name 	: V_1135
# particles 	: [W__minus__, Z2, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_415}
# name 	: V_1149
# particles 	: [W2__minus__, Z2, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_356}
# name 	: V_1151
# particles 	: [W2__minus__, Z2, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_436}
# name 	: V_1167
# particles 	: [W2__plus__, Z2, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_356}
# name 	: V_1169
# particles 	: [W2__plus__, Z2, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_436}
# name 	: V_1185
# particles 	: [W__plus__, Z2, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_410}
# name 	: V_1191
# particles 	: [W__plus__, Z2, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_415}
# name 	: V_1209
# particles 	: [Z, Z2, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_377}
# name 	: V_1212
# particles 	: [Z, Z2, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_751}
# name 	: V_1230
# particles 	: [Z2, Z2, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_372}
# name 	: V_1233
# particles 	: [Z2, Z2, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_749}
# name 	: V_69
# particles 	: [A01, A01, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_296}
# name 	: V_70
# particles 	: [G01, G01, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_300}
# name 	: V_71
# particles 	: [GL__minus__, GL__plus__, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_300}
# name 	: V_72
# particles 	: [H, H, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_304}
# name 	: V_76
# particles 	: [H, H, H01, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_298}
# name 	: V_81
# particles 	: [H, H, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_291}
# name 	: V_84
# particles 	: [A01, G01, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_292}
# name 	: V_86
# particles 	: [A01, GL__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_299}
# name 	: V_88
# particles 	: [GL__plus__, H, H01, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_295}
# name 	: V_91
# particles 	: [A01, GL__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_294}
# name 	: V_93
# particles 	: [GL__minus__, H, H01, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_295}
# name 	: V_98
# particles 	: [A01, G01, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_309}
# name 	: V_99
# particles 	: [A01, A01, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_308}
# name 	: V_100
# particles 	: [G01, G01, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_309}
# name 	: V_101
# particles 	: [GL__minus__, GL__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_309}
# name 	: V_102
# particles 	: [H, H, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_313}
# name 	: V_104
# particles 	: [H, H01, H01, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_312}
# name 	: V_108
# particles 	: [GL__plus__, H, H, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_306}
# name 	: V_113
# particles 	: [GL__minus__, H, H, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_306}
# name 	: V_116
# particles 	: [H, H01, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_308}
# name 	: V_119
# particles 	: [A01, A01, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_318}
# name 	: V_120
# particles 	: [G01, G01, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_321}
# name 	: V_121
# particles 	: [GL__minus__, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_321}
# name 	: V_122
# particles 	: [H, H, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_322}
# name 	: V_123
# particles 	: [H, H01, H01]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_319}
# name 	: V_124
# particles 	: [H, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_314}
# name 	: V_130
# particles 	: [A01, G01, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_325}
# name 	: V_134
# particles 	: [H, H, H01]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_327}
# name 	: V_136
# particles 	: [GL__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_323}
# name 	: V_137
# particles 	: [GL__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_323}
# name 	: V_153
# particles 	: [G02, GL__plus__, GR__minus__, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_345}
# name 	: V_154
# particles 	: [G02, GL__minus__, GR__plus__, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_343}
# name 	: V_155
# particles 	: [A02, A02, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_340}
# name 	: V_156
# particles 	: [G02, G02, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_340}
# name 	: V_157
# particles 	: [GR__minus__, GR__plus__, H, H]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_338}
# name 	: V_158
# particles 	: [A02, A02, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_334}
# name 	: V_159
# particles 	: [G02, G02, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_334}
# name 	: V_160
# particles 	: [GR__minus__, GR__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_333}
# name 	: V_166
# particles 	: [GL__plus__, GR__minus__, H, H02]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_344}
# name 	: V_167
# particles 	: [GL__minus__, GR__plus__, H, H02]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_344}
# name 	: V_172
# particles 	: [H, H, H02, H02]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_340}
# name 	: V_173
# particles 	: [H, H01, H02, H02]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_334}
# name 	: V_179
# particles 	: [H, H, H03, H03]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_340}
# name 	: V_180
# particles 	: [H, H01, H03, H03]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_334}
# name 	: V_183
# particles 	: [A02, GL__plus__, H, HM1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_345}
# name 	: V_185
# particles 	: [GL__plus__, H, H03, HM1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_344}
# name 	: V_187
# particles 	: [A02, GL__minus__, H, HP1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_343}
# name 	: V_189
# particles 	: [GL__minus__, H, H03, HP1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_344}
# name 	: V_194
# particles 	: [H, H, HM1, HP1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_338}
# name 	: V_195
# particles 	: [H, H01, HM1, HP1]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_333}
# name 	: V_232
# particles 	: [GL__plus__, H, HP1, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_337}
# name 	: V_236
# particles 	: [GL__minus__, H, HM1, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_337}
# name 	: V_243
# particles 	: [H, H, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_328}
# name 	: V_244
# particles 	: [H, H01, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_335}
# name 	: V_250
# particles 	: [GL__plus__, GR__plus__, H, HR__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_337}
# name 	: V_254
# particles 	: [GL__minus__, GR__minus__, H, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_337}
# name 	: V_261
# particles 	: [H, H, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_328}
# name 	: V_262
# particles 	: [H, H01, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_335}
# name 	: V_284
# particles 	: [G02, GR__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_778}
# name 	: V_286
# particles 	: [GR__plus__, H, H02, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_776}
# name 	: V_288
# particles 	: [A02, H, HP1, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_778}
# name 	: V_290
# particles 	: [H, H03, HP1, HM2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_776}
# name 	: V_292
# particles 	: [G02, GR__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_775}
# name 	: V_294
# particles 	: [GR__minus__, H, H02, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_776}
# name 	: V_296
# particles 	: [A02, H, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_775}
# name 	: V_298
# particles 	: [H, H03, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_776}
# name 	: V_302
# particles 	: [H, HP1, HP2, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_773}
# name 	: V_306
# particles 	: [H, HM1, HM2, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_773}
# name 	: V_310
# particles 	: [GR__plus__, H, HP2, HR__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_773}
# name 	: V_314
# particles 	: [GR__minus__, H, HM2, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_773}
# name 	: V_317
# particles 	: [A02, A02, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_466}
# name 	: V_318
# particles 	: [G02, G02, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_466}
# name 	: V_319
# particles 	: [GR__minus__, GR__plus__, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_465}
# name 	: V_325
# particles 	: [H, H02, H02]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_466}
# name 	: V_327
# particles 	: [H, H03, H03]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_466}
# name 	: V_333
# particles 	: [H, HM1, HP1]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_465}
# name 	: V_337
# particles 	: [H, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_460}
# name 	: V_341
# particles 	: [H, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_460}
# name 	: V_375
# particles 	: [H, H, H03]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_820}
# name 	: V_376
# particles 	: [H, H01, H03]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_819}
# name 	: V_379
# particles 	: [GL__plus__, H, HM1]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_823}
# name 	: V_381
# particles 	: [GL__minus__, H, HP1]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_823}
# name 	: V_394
# particles 	: [H, HP1, HM2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_800}
# name 	: V_396
# particles 	: [H, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_800}
# name 	: V_415
# particles 	: [GL__plus__, GR__minus__, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_971}
# name 	: V_416
# particles 	: [GL__minus__, GR__plus__, H]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_971}
# name 	: V_421
# particles 	: [H, H, H02]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_968}
# name 	: V_422
# particles 	: [H, H01, H02]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_967}
# name 	: V_436
# particles 	: [GR__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_948}
# name 	: V_438
# particles 	: [GR__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_948}
# name 	: V_501
# particles 	: [d__tilde__, d, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_975}
# name 	: V_502
# particles 	: [s__tilde__, s, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_979}
# name 	: V_503
# particles 	: [b__tilde__, b, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_983}
# name 	: V_507
# particles 	: [u__tilde__, u, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_1000}
# name 	: V_508
# particles 	: [c__tilde__, c, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_1004}
# name 	: V_509
# particles 	: [t__tilde__, t, H]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_1008}
# name 	: V_555
# particles 	: [N1, N1, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_675, (0, 1): GC_694}
# name 	: V_556
# particles 	: [N4, N1, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_681, (0, 1): GC_700}
# name 	: V_557
# particles 	: [N2, N2, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_677, (0, 1): GC_696}
# name 	: V_558
# particles 	: [N5, N2, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_685, (0, 1): GC_704}
# name 	: V_559
# particles 	: [N3, N3, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_679, (0, 1): GC_698}
# name 	: V_560
# particles 	: [N6, N3, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_689, (0, 1): GC_708}
# name 	: V_561
# particles 	: [N4, N4, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_683, (0, 1): GC_702}
# name 	: V_562
# particles 	: [N5, N5, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_687, (0, 1): GC_706}
# name 	: V_563
# particles 	: [N6, N6, H]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_691, (0, 1): GC_710}
# name 	: V_615
# particles 	: [e__plus__, e__minus__, H]
# color 	: ['1']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_987}
# name 	: V_616
# particles 	: [mu__plus__, mu__minus__, H]
# color 	: ['1']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_991}
# name 	: V_617
# particles 	: [ta__plus__, ta__minus__, H]
# color 	: ['1']
# lorentz 	: [FFS4]
# couplings 	: {(0, 0): GC_995}
# name 	: V_679
# particles 	: [a, W__minus__, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_420}
# name 	: V_685
# particles 	: [a, W__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_428}
# name 	: V_696
# particles 	: [W__minus__, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_378}
# name 	: V_700
# particles 	: [W__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_395}
# name 	: V_723
# particles 	: [a, W2__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_361}
# name 	: V_725
# particles 	: [a, W2__minus__, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_427}
# name 	: V_739
# particles 	: [W2__minus__, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_393}
# name 	: V_742
# particles 	: [W2__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_347}
# name 	: V_774
# particles 	: [a, W2__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_361}
# name 	: V_776
# particles 	: [a, W2__plus__, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_427}
# name 	: V_790
# particles 	: [W2__plus__, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_396}
# name 	: V_793
# particles 	: [W2__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_348}
# name 	: V_806
# particles 	: [W__minus__, W2__plus__, A01, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_452}
# name 	: V_808
# particles 	: [W__minus__, W2__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_453}
# name 	: V_811
# particles 	: [W__minus__, W2__plus__, G01, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_451}
# name 	: V_812
# particles 	: [W__minus__, W2__plus__, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_448}
# name 	: V_818
# particles 	: [W__minus__, W2__plus__, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_764}
# name 	: V_834
# particles 	: [W2__minus__, W2__plus__, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_456}
# name 	: V_838
# particles 	: [W2__minus__, W2__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_405}
# name 	: V_839
# particles 	: [W2__minus__, W2__plus__, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_768}
# name 	: V_865
# particles 	: [a, W__plus__, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_420}
# name 	: V_871
# particles 	: [a, W__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_428}
# name 	: V_882
# particles 	: [W__plus__, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_381}
# name 	: V_886
# particles 	: [W__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_394}
# name 	: V_901
# particles 	: [W__minus__, W__plus__, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_457}
# name 	: V_905
# particles 	: [W__minus__, W__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_404}
# name 	: V_906
# particles 	: [W__minus__, W__plus__, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_769}
# name 	: V_922
# particles 	: [W2__minus__, W__plus__, A01, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_459}
# name 	: V_924
# particles 	: [W2__minus__, W__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_453}
# name 	: V_927
# particles 	: [W2__minus__, W__plus__, G01, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_446}
# name 	: V_928
# particles 	: [W2__minus__, W__plus__, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_448}
# name 	: V_934
# particles 	: [W2__minus__, W__plus__, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_764}
# name 	: V_995
# particles 	: [Z, G01, H]
# color 	: ['1']
# lorentz 	: [VSS2]
# couplings 	: {(0, 0): GC_368}
# name 	: V_1010
# particles 	: [W__minus__, Z, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_387}
# name 	: V_1016
# particles 	: [W__minus__, Z, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_401}
# name 	: V_1030
# particles 	: [W2__minus__, Z, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_352}
# name 	: V_1032
# particles 	: [W2__minus__, Z, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_443}
# name 	: V_1048
# particles 	: [W2__plus__, Z, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_352}
# name 	: V_1050
# particles 	: [W2__plus__, Z, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_443}
# name 	: V_1066
# particles 	: [W__plus__, Z, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_387}
# name 	: V_1072
# particles 	: [W__plus__, Z, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_401}
# name 	: V_1090
# particles 	: [Z, Z, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_375}
# name 	: V_1093
# particles 	: [Z, Z, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_750}
# name 	: V_1114
# particles 	: [Z2, G01, H]
# color 	: ['1']
# lorentz 	: [VSS1, VSS3]
# couplings 	: {(0, 0): GC_367, (0, 1): GC_364}
# name 	: V_1129
# particles 	: [W__minus__, Z2, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_410}
# name 	: V_1135
# particles 	: [W__minus__, Z2, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_415}
# name 	: V_1149
# particles 	: [W2__minus__, Z2, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_356}
# name 	: V_1151
# particles 	: [W2__minus__, Z2, GL__plus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_436}
# name 	: V_1167
# particles 	: [W2__plus__, Z2, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_356}
# name 	: V_1169
# particles 	: [W2__plus__, Z2, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_436}
# name 	: V_1185
# particles 	: [W__plus__, Z2, GL__minus__, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_410}
# name 	: V_1191
# particles 	: [W__plus__, Z2, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_415}
# name 	: V_1209
# particles 	: [Z, Z2, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_377}
# name 	: V_1212
# particles 	: [Z, Z2, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_751}
# name 	: V_1230
# particles 	: [Z2, Z2, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_372}
# name 	: V_1233
# particles 	: [Z2, Z2, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_749}

# %%
#vertices_H3 = [
#    vertex for vertex in vertices_H if (
#        L.FFS1 in vertex.lorentz
#        or L.FFS2 in vertex.lorentz
#        or L.FFS3 in vertex.lorentz
#        or L.FFS4 in vertex.lorentz
#    )
#]
#print(len(vertices_H3), 'vertices of three particles with H')

# %%
vertices_HFF = [
    vertex for vertex in vertices_H if all([lorentz.spins == [2,2,1] for lorentz in vertex.lorentz])
]
print(len(vertices_HFF), 'vertices of the type HFF')
# Out:
# 36 vertices of the type HFF

# %%
for vertex in vertices_HFF:
    print(vertex.particles, vertex.lorentz)
    #print(vertex.nice_string())
# Out:
# [d__tilde__, d, H] [FFS4]
# [s__tilde__, s, H] [FFS4]
# [b__tilde__, b, H] [FFS4]
# [u__tilde__, u, H] [FFS4]
# [c__tilde__, c, H] [FFS4]
# [t__tilde__, t, H] [FFS4]
# [N1, N1, H] [FFS1, FFS3]
# [N4, N1, H] [FFS1, FFS3]
# [N2, N2, H] [FFS1, FFS3]
# [N5, N2, H] [FFS1, FFS3]
# [N3, N3, H] [FFS1, FFS3]
# [N6, N3, H] [FFS1, FFS3]
# [N4, N4, H] [FFS1, FFS3]
# [N5, N5, H] [FFS1, FFS3]
# [N6, N6, H] [FFS1, FFS3]
# [e__plus__, e__minus__, H] [FFS4]
# [mu__plus__, mu__minus__, H] [FFS4]
# [ta__plus__, ta__minus__, H] [FFS4]
# [d__tilde__, d, H] [FFS4]
# [s__tilde__, s, H] [FFS4]
# [b__tilde__, b, H] [FFS4]
# [u__tilde__, u, H] [FFS4]
# [c__tilde__, c, H] [FFS4]
# [t__tilde__, t, H] [FFS4]
# [N1, N1, H] [FFS1, FFS3]
# [N4, N1, H] [FFS1, FFS3]
# [N2, N2, H] [FFS1, FFS3]
# [N5, N2, H] [FFS1, FFS3]
# [N3, N3, H] [FFS1, FFS3]
# [N6, N3, H] [FFS1, FFS3]
# [N4, N4, H] [FFS1, FFS3]
# [N5, N5, H] [FFS1, FFS3]
# [N6, N6, H] [FFS1, FFS3]
# [e__plus__, e__minus__, H] [FFS4]
# [mu__plus__, mu__minus__, H] [FFS4]
# [ta__plus__, ta__minus__, H] [FFS4]

# %%
couplings.GC_504.value
# Out:
# '-0.5*(complex(0,1)*I17c14*k1**2)/((k1 - k2)*(k1 + k2)*vev) - (complex(0,1)*I17c41*k1**2)/(2.*(k1 - k2)*(k1 + k2)*vev) - (complex(0,1)*I18c14*k1**2)/(2.*(k1 - k2)*(k1 + k2)*vev) - (complex(0,1)*I18c41*k1**2)/(2.*(k1 - k2)*(k1 + k2)*vev) + (complex(0,1)*I13c14*k1*k2)/((k1 - k2)*(k1 + k2)*vev) + (complex(0,1)*I13c41*k1*k2)/((k1 - k2)*(k1 + k2)*vev) + (complex(0,1)*I14c14*k1*k2)/((k1 - k2)*(k1 + k2)*vev) + (complex(0,1)*I14c41*k1*k2)/((k1 - k2)*(k1 + k2)*vev) - (complex(0,1)*I17c14*k2**2)/(2.*(k1 - k2)*(k1 + k2)*vev) - (complex(0,1)*I17c41*k2**2)/(2.*(k1 - k2)*(k1 + k2)*vev) - (complex(0,1)*I18c14*k2**2)/(2.*(k1 - k2)*(k1 + k2)*vev) - (complex(0,1)*I18c41*k2**2)/(2.*(k1 - k2)*(k1 + k2)*vev)'

# %%
gRd = sympify(couplings.GC_504.value.replace('complex(0,1)', '1j')).factor()
gLd = sympify(couplings.GC_513.value.replace('complex(0,1)', '1j')).factor()
display(gRd, gLd)
# Out:
#        ⎛                                                                       ↪
# -1.0⋅ⅈ⋅⎝-1.0⋅I13c14⋅k₁⋅k₂ - 1.0⋅I13c41⋅k₁⋅k₂ - 1.0⋅I14c14⋅k₁⋅k₂ - 1.0⋅I14c41⋅k ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#
# ↪                     2                2                2                2     ↪
# ↪ ₁⋅k₂ + 0.5⋅I17c14⋅k₁  + 0.5⋅I17c14⋅k₂  + 0.5⋅I17c41⋅k₁  + 0.5⋅I17c41⋅k₂  + 0 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                     vev⋅(k₁ - k₂)⋅(k₁ + k₂)                                  ↪
#
# ↪             2                2                2                2⎞
# ↪ .5⋅I18c14⋅k₁  + 0.5⋅I18c14⋅k₂  + 0.5⋅I18c41⋅k₁  + 0.5⋅I18c41⋅k₂ ⎠
# ↪ ──────────────────────────────────────────────────────────────────
# ↪
#     ⎛                                                                          ↪
# 1.0⋅⎝-1.0⋅I13c36⋅k₁⋅k₂ - 1.0⋅I13c63⋅k₁⋅k₂ - 1.0⋅I14c36⋅k₁⋅k₂ - 1.0⋅I14c63⋅k₁⋅k ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#
# ↪                  2                2                2                2        ↪
# ↪ ₂ + 0.5⋅I17c36⋅k₁  + 0.5⋅I17c36⋅k₂  + 0.5⋅I17c63⋅k₁  + 0.5⋅I17c63⋅k₂  + 0.5⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                   vev⋅(k₁ - k₂)⋅(k₁ + k₂)                                    ↪
#
# ↪          2                2                2                2⎞
# ↪ I18c36⋅k₁  + 0.5⋅I18c36⋅k₂  + 0.5⋅I18c63⋅k₁  + 0.5⋅I18c63⋅k₂ ⎠
# ↪ ──────────────────────────────────────────────────────────────
# ↪

# %%
sympify(parameters.I13a55.value)
# Out:
#                                       2      2
# KL2x2⋅KL5x2⋅KR2x2⋅KR5x2⋅yNL2x2 + KL5x2 ⋅KR5x2 ⋅yNL5x5

# %% [markdown]
# # Z interactions

# %%
vertices_Z = [
    vertex for vertex in vertices.all_vertices if particles.Z in vertex.particles
]
print(len(vertices_Z), 'vertices with Z')
# Out:
# 107 vertices with Z

# %%
for vertex in vertices_Z:
    print(vertex.nice_string())
# Out:
# name 	: V_400
# particles 	: [W__minus__, W2__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVV1]
# couplings 	: {(0, 0): GC_221}
# name 	: V_418
# particles 	: [W2__minus__, W2__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVV1]
# couplings 	: {(0, 0): GC_235}
# name 	: V_459
# particles 	: [W__minus__, W__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVV1]
# couplings 	: {(0, 0): GC_245}
# name 	: V_478
# particles 	: [W2__minus__, W__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVV1]
# couplings 	: {(0, 0): GC_221}
# name 	: V_510
# particles 	: [a, Z, H02, H02]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_148}
# name 	: V_511
# particles 	: [a, Z, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_147}
# name 	: V_512
# particles 	: [a, Z, A02, A02]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_146}
# name 	: V_513
# particles 	: [a, Z, H03, H03]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_146}
# name 	: V_514
# particles 	: [a, Z, HM1, HP1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_140}
# name 	: V_515
# particles 	: [a, Z, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_145}
# name 	: V_516
# particles 	: [a, Z, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_298}
# name 	: V_517
# particles 	: [a, Z, H03]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_595}
# name 	: V_518
# particles 	: [a, Z, H02]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_702}
# name 	: V_519
# particles 	: [Z, A01, H01]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_295}
# name 	: V_520
# particles 	: [Z, A02, H03]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_123}
# name 	: V_521
# particles 	: [Z, HM1, HP1]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_125}
# name 	: V_522
# particles 	: [Z, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_296}
# name 	: V_523
# particles 	: [Z, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_126}
# name 	: V_524
# particles 	: [Z, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_127}
# name 	: V_525
# particles 	: [W__minus__, Z, A02, HP1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_134}
# name 	: V_526
# particles 	: [W__minus__, Z, H03, HP1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_133}
# name 	: V_527
# particles 	: [W__minus__, Z, HM1, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_131}
# name 	: V_528
# particles 	: [W__minus__, Z, A01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_308}
# name 	: V_529
# particles 	: [W__minus__, Z, H01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_309}
# name 	: V_530
# particles 	: [W__minus__, Z, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_316}
# name 	: V_531
# particles 	: [W__minus__, Z, HP2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_557}
# name 	: V_532
# particles 	: [W__minus__, Z, HP1]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_593}
# name 	: V_533
# particles 	: [W2__minus__, Z, A02, HP1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_225}
# name 	: V_534
# particles 	: [W2__minus__, Z, H03, HP1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_224}
# name 	: V_535
# particles 	: [W2__minus__, Z, HM1, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_222}
# name 	: V_536
# particles 	: [W2__minus__, Z, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_288}
# name 	: V_537
# particles 	: [W2__minus__, Z, A01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_335}
# name 	: V_538
# particles 	: [W2__minus__, Z, H01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_334}
# name 	: V_539
# particles 	: [W2__minus__, Z, HP2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_353}
# name 	: V_540
# particles 	: [W2__minus__, Z, HP1]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_601}
# name 	: V_541
# particles 	: [W2__plus__, Z, A02, HM1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_223}
# name 	: V_542
# particles 	: [W2__plus__, Z, H03, HM1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_224}
# name 	: V_543
# particles 	: [W2__plus__, Z, HP1, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_222}
# name 	: V_544
# particles 	: [W2__plus__, Z, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_288}
# name 	: V_545
# particles 	: [W2__plus__, Z, A01, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_333}
# name 	: V_546
# particles 	: [W2__plus__, Z, H01, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_334}
# name 	: V_547
# particles 	: [W2__plus__, Z, HM2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_353}
# name 	: V_548
# particles 	: [W2__plus__, Z, HM1]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_601}
# name 	: V_549
# particles 	: [a, W__minus__, W2__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVVV5]
# couplings 	: {(0, 0): GC_231}
# name 	: V_550
# particles 	: [a, W2__minus__, W2__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVVV5]
# couplings 	: {(0, 0): GC_241}
# name 	: V_551
# particles 	: [W__plus__, Z, A02, HM1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_132}
# name 	: V_552
# particles 	: [W__plus__, Z, H03, HM1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_133}
# name 	: V_553
# particles 	: [W__plus__, Z, HP1, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_131}
# name 	: V_554
# particles 	: [W__plus__, Z, A01, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_310}
# name 	: V_555
# particles 	: [W__plus__, Z, H01, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_309}
# name 	: V_556
# particles 	: [W__plus__, Z, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_316}
# name 	: V_557
# particles 	: [W__plus__, Z, HM2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_557}
# name 	: V_558
# particles 	: [W__plus__, Z, HM1]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_593}
# name 	: V_559
# particles 	: [a, W__minus__, W__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVVV5]
# couplings 	: {(0, 0): GC_247}
# name 	: V_560
# particles 	: [a, W2__minus__, W__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVVV5]
# couplings 	: {(0, 0): GC_231}
# name 	: V_561
# particles 	: [Z, Z, A02, A02]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_151}
# name 	: V_562
# particles 	: [Z, Z, H03, H03]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_151}
# name 	: V_563
# particles 	: [Z, Z, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_150}
# name 	: V_564
# particles 	: [Z, Z, H02, H02]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_162}
# name 	: V_565
# particles 	: [Z, Z, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_163}
# name 	: V_566
# particles 	: [Z, Z, HM1, HP1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_149}
# name 	: V_567
# particles 	: [Z, Z, A01, A01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_302}
# name 	: V_568
# particles 	: [Z, Z, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_302}
# name 	: V_569
# particles 	: [Z, Z, H01, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_302}
# name 	: V_570
# particles 	: [Z, Z, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_301}
# name 	: V_571
# particles 	: [Z, Z, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_555}
# name 	: V_572
# particles 	: [Z, Z, H03]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_596}
# name 	: V_573
# particles 	: [Z, Z, H02]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_704}
# name 	: V_574
# particles 	: [W__minus__, W2__plus__, Z, Z]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_232}
# name 	: V_575
# particles 	: [W2__minus__, W2__plus__, Z, Z]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_236}
# name 	: V_576
# particles 	: [W__minus__, W__plus__, Z, Z]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_249}
# name 	: V_577
# particles 	: [W2__minus__, W__plus__, Z, Z]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_232}
# name 	: V_629
# particles 	: [Z, Z2, A02, A02]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_161}
# name 	: V_630
# particles 	: [Z, Z2, H02, H02]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_164}
# name 	: V_631
# particles 	: [Z, Z2, H03, H03]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_161}
# name 	: V_632
# particles 	: [Z, Z2, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_160}
# name 	: V_633
# particles 	: [Z, Z2, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_165}
# name 	: V_634
# particles 	: [Z, Z2, HM1, HP1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_159}
# name 	: V_635
# particles 	: [Z, Z2, A01, A01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_304}
# name 	: V_636
# particles 	: [Z, Z2, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_304}
# name 	: V_637
# particles 	: [Z, Z2, H01, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_304}
# name 	: V_638
# particles 	: [Z, Z2, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_303}
# name 	: V_639
# particles 	: [Z, Z2, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_556}
# name 	: V_640
# particles 	: [Z, Z2, H03]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_599}
# name 	: V_641
# particles 	: [Z, Z2, H02]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_705}
# name 	: V_642
# particles 	: [W__minus__, W2__plus__, Z, Z2]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_234}
# name 	: V_643
# particles 	: [W2__minus__, W2__plus__, Z, Z2]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_238}
# name 	: V_644
# particles 	: [W__minus__, W__plus__, Z, Z2]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_250}
# name 	: V_645
# particles 	: [W2__minus__, W__plus__, Z, Z2]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_234}
# name 	: V_675
# particles 	: [N1, N1, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_105, (0, 1): GC_111}
# name 	: V_676
# particles 	: [N4, N1, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_117, (0, 1): GC_112}
# name 	: V_677
# particles 	: [N2, N2, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_106, (0, 1): GC_113}
# name 	: V_678
# particles 	: [N5, N2, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_119, (0, 1): GC_114}
# name 	: V_679
# particles 	: [N3, N3, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_107, (0, 1): GC_115}
# name 	: V_680
# particles 	: [N6, N3, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_121, (0, 1): GC_116}
# name 	: V_681
# particles 	: [N4, N4, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_108, (0, 1): GC_118}
# name 	: V_682
# particles 	: [N5, N5, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_109, (0, 1): GC_120}
# name 	: V_683
# particles 	: [N6, N6, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_110, (0, 1): GC_122}
# name 	: V_708
# particles 	: [e__plus__, e__minus__, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3, FFV5, FFV6]
# couplings 	: {(0, 0): GC_4, (0, 2): GC_67, (0, 3): GC_69, (0, 1): GC_77}
# name 	: V_709
# particles 	: [mu__plus__, mu__minus__, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3, FFV5, FFV6]
# couplings 	: {(0, 0): GC_4, (0, 2): GC_67, (0, 3): GC_69, (0, 1): GC_77}
# name 	: V_710
# particles 	: [ta__plus__, ta__minus__, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3, FFV5, FFV6]
# couplings 	: {(0, 0): GC_4, (0, 2): GC_67, (0, 3): GC_69, (0, 1): GC_77}
# name 	: V_738
# particles 	: [u__tilde__, u, Z]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFV2, FFV3, FFV5, FFV7]
# couplings 	: {(0, 0): GC_5, (0, 2): GC_66, (0, 3): GC_68, (0, 1): GC_76}
# name 	: V_739
# particles 	: [c__tilde__, c, Z]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFV2, FFV3, FFV5, FFV7]
# couplings 	: {(0, 0): GC_5, (0, 2): GC_66, (0, 3): GC_68, (0, 1): GC_76}
# name 	: V_740
# particles 	: [t__tilde__, t, Z]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFV2, FFV3, FFV5, FFV7]
# couplings 	: {(0, 0): GC_5, (0, 2): GC_66, (0, 3): GC_68, (0, 1): GC_76}
# name 	: V_768
# particles 	: [d__tilde__, d, Z]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFV2, FFV3, FFV5]
# couplings 	: {(0, 0): GC_124, (0, 2): GC_66, (0, 1): GC_104}
# name 	: V_769
# particles 	: [s__tilde__, s, Z]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFV2, FFV3, FFV5]
# couplings 	: {(0, 0): GC_124, (0, 2): GC_66, (0, 1): GC_104}
# name 	: V_770
# particles 	: [b__tilde__, b, Z]
# color 	: ['Identity(1,2)']
# lorentz 	: [FFV2, FFV3, FFV5]
# couplings 	: {(0, 0): GC_124, (0, 2): GC_66, (0, 1): GC_104}

# %% [markdown]
# ## Vertexez ZFF

# %%
#vertices_Z3 = [
#    vertex for vertex in vertices_Z if (
#        L.FFV1 in vertex.lorentz
#        or L.FFV2 in vertex.lorentz
#        or L.FFV3 in vertex.lorentz
#        or L.FFV4 in vertex.lorentz
#        or L.FFV5 in vertex.lorentz
#        or L.FFV7 in vertex.lorentz
#    )
#]
#print(len(vertices_Z3), 'vertices of three particles with Z')

# %%
vertices_ZFF = [
    vertex for vertex in vertices_Z if all([lorentz.spins == [2,2,3] for lorentz in vertex.lorentz])
]
print(len(vertices_ZFF), 'vertices of the type ZFF')
# Out:
# 18 vertices of the type ZFF

# %%
for vertex in vertices_ZFF:
    print(vertex.particles, vertex.lorentz)
    #print(vertex.nice_string())
# Out:
# [N1, N1, Z] [FFV2, FFV3]
# [N4, N1, Z] [FFV2, FFV3]
# [N2, N2, Z] [FFV2, FFV3]
# [N5, N2, Z] [FFV2, FFV3]
# [N3, N3, Z] [FFV2, FFV3]
# [N6, N3, Z] [FFV2, FFV3]
# [N4, N4, Z] [FFV2, FFV3]
# [N5, N5, Z] [FFV2, FFV3]
# [N6, N6, Z] [FFV2, FFV3]
# [e__plus__, e__minus__, Z] [FFV2, FFV3, FFV5, FFV6]
# [mu__plus__, mu__minus__, Z] [FFV2, FFV3, FFV5, FFV6]
# [ta__plus__, ta__minus__, Z] [FFV2, FFV3, FFV5, FFV6]
# [u__tilde__, u, Z] [FFV2, FFV3, FFV5, FFV7]
# [c__tilde__, c, Z] [FFV2, FFV3, FFV5, FFV7]
# [t__tilde__, t, Z] [FFV2, FFV3, FFV5, FFV7]
# [d__tilde__, d, Z] [FFV2, FFV3, FFV5]
# [s__tilde__, s, Z] [FFV2, FFV3, FFV5]
# [b__tilde__, b, Z] [FFV2, FFV3, FFV5]

# %%
print(vertices_ZFF[0].nice_string())
# Out:
# name 	: V_675
# particles 	: [N1, N1, Z]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_105, (0, 1): GC_111}

# %% [markdown]
# ## Vertexes ZSS

# %%
vertices_ZSS = [
    vertex for vertex in vertices_Z if all([lorentz.spins == [3, 1, 1] for lorentz in vertex.lorentz])
]
print(len(vertices_ZSS), 'vertices of the type ZSS')
# Out:
# 6 vertices of the type ZSS

# %%
for vertex in vertices_ZSS:
    print(vertex.particles, vertex.lorentz)
    #print(vertex.nice_string())
# Out:
# [Z, A01, H01] [VSS1]
# [Z, A02, H03] [VSS1]
# [Z, HM1, HP1] [VSS1]
# [Z, HM2, HP2] [VSS1]
# [Z, HL__minus____minus__, HL__plus____plus__] [VSS1]
# [Z, HR__minus____minus__, HR__plus____plus__] [VSS1]

# %% [markdown]
# ## Vertexes ZVV

# %%
vertices_ZVV = [
    vertex for vertex in vertices_Z if all([lorentz.spins == [3, 3, 3] for lorentz in vertex.lorentz])
]
print(len(vertices_ZVV), 'vertices of the type ZVV')
# Out:
# 4 vertices of the type ZVV

# %%
for vertex in vertices_ZVV:
    print(vertex.particles, vertex.lorentz)
    #print(vertex.nice_string())
# Out:
# [W__minus__, W2__plus__, Z] [VVV1]
# [W2__minus__, W2__plus__, Z] [VVV1]
# [W__minus__, W__plus__, Z] [VVV1]
# [W2__minus__, W__plus__, Z] [VVV1]

# %% [markdown]
# ## Vertexes ZSV

# %%
vertices_ZSV = [
    vertex for vertex in vertices_Z if all([lorentz.spins == [3, 3, 1] for lorentz in vertex.lorentz])
]
print(len(vertices_ZSV), 'vertices of the type ZSV')
# Out:
# 16 vertices of the type ZSV

# %%
for vertex in vertices_ZSV:
    print(vertex.particles, vertex.lorentz)
    #print(vertex.nice_string())
# Out:
# [a, Z, H03] [VVS1]
# [a, Z, H02] [VVS1]
# [W__minus__, Z, HP2] [VVS1]
# [W__minus__, Z, HP1] [VVS1]
# [W2__minus__, Z, HP2] [VVS1]
# [W2__minus__, Z, HP1] [VVS1]
# [W2__plus__, Z, HM2] [VVS1]
# [W2__plus__, Z, HM1] [VVS1]
# [W__plus__, Z, HM2] [VVS1]
# [W__plus__, Z, HM1] [VVS1]
# [Z, Z, H] [VVS1]
# [Z, Z, H03] [VVS1]
# [Z, Z, H02] [VVS1]
# [Z, Z2, H] [VVS1]
# [Z, Z2, H03] [VVS1]
# [Z, Z2, H02] [VVS1]

# %% [markdown]
# # Interactions with Charged scalars

# %% [markdown]
# ## Interactions with $H_{1,2}^+$

# %%
vertices_HP1 = [
    vertex for vertex in vertices.all_vertices if particles.HP1 in vertex.particles and vertex.color == ['1']
]
print(len(vertices_HP1), 'vertices with HP1')

vertices_HP2 = [
    vertex for vertex in vertices.all_vertices if particles.HP2 in vertex.particles and vertex.color == ['1']
]
print(len(vertices_HP2), 'vertices with HP2')
# Out:
# 84 vertices with HP1
# 80 vertices with HP2

# %%
for vertex in vertices_HP2:
    print(vertex.nice_string())
# Out:
# name 	: V_38
# particles 	: [A01, A01, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_257}
# name 	: V_39
# particles 	: [H, H, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_254}
# name 	: V_40
# particles 	: [H01, H01, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_257}
# name 	: V_41
# particles 	: [HM2, HM2, HP2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_258}
# name 	: V_45
# particles 	: [H, H01, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_261}
# name 	: V_49
# particles 	: [H, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_264}
# name 	: V_53
# particles 	: [H01, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_268}
# name 	: V_74
# particles 	: [A01, A02, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_284}
# name 	: V_75
# particles 	: [A02, H01, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_285}
# name 	: V_76
# particles 	: [A01, H03, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_283}
# name 	: V_77
# particles 	: [H01, H03, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_284}
# name 	: V_78
# particles 	: [A02, A02, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_281}
# name 	: V_79
# particles 	: [H02, H02, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_281}
# name 	: V_80
# particles 	: [H03, H03, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_281}
# name 	: V_81
# particles 	: [HM1, HP1, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_279}
# name 	: V_82
# particles 	: [A01, HP1, HP2, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_282}
# name 	: V_83
# particles 	: [H01, HP1, HP2, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_277}
# name 	: V_90
# particles 	: [HM2, HP2, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_272}
# name 	: V_95
# particles 	: [HM2, HP2, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_272}
# name 	: V_98
# particles 	: [A02, H, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_569}
# name 	: V_99
# particles 	: [H, H03, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_570}
# name 	: V_100
# particles 	: [H, HP1, HP2, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_568}
# name 	: V_116
# particles 	: [A02, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_575}
# name 	: V_117
# particles 	: [H03, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_576}
# name 	: V_118
# particles 	: [HP1, HP2, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_574}
# name 	: V_136
# particles 	: [A01, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_607}
# name 	: V_137
# particles 	: [H01, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_608}
# name 	: V_138
# particles 	: [H03, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_606}
# name 	: V_140
# particles 	: [H, HM1, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_589}
# name 	: V_157
# particles 	: [H02, HM2, HP2]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_710}
# name 	: V_164
# particles 	: [a, a, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_292}
# name 	: V_169
# particles 	: [a, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_290}
# name 	: V_261
# particles 	: [N1, e__minus__, HP2]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_417, (0, 1): GC_423}
# name 	: V_262
# particles 	: [N4, e__minus__, HP2]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_420, (0, 1): GC_426}
# name 	: V_263
# particles 	: [N2, mu__minus__, HP2]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_418, (0, 1): GC_424}
# name 	: V_264
# particles 	: [N5, mu__minus__, HP2]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_421, (0, 1): GC_427}
# name 	: V_265
# particles 	: [N3, ta__minus__, HP2]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_419, (0, 1): GC_425}
# name 	: V_266
# particles 	: [N6, ta__minus__, HP2]
# color 	: ['1']
# lorentz 	: [FFS1, FFS3]
# couplings 	: {(0, 0): GC_422, (0, 1): GC_428}
# name 	: V_324
# particles 	: [a, W__minus__, A01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_323}
# name 	: V_325
# particles 	: [a, W__minus__, H01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_324}
# name 	: V_326
# particles 	: [a, W__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_327}
# name 	: V_327
# particles 	: [a, W__minus__, HP2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_561}
# name 	: V_329
# particles 	: [W__minus__, A01, HP2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_307}
# name 	: V_331
# particles 	: [W__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_313}
# name 	: V_332
# particles 	: [W__minus__, H01, HP2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_306}
# name 	: V_339
# particles 	: [W__minus__, W__minus__, HP2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_573}
# name 	: V_345
# particles 	: [a, W2__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_291}
# name 	: V_346
# particles 	: [a, W2__minus__, A01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_326}
# name 	: V_347
# particles 	: [a, W2__minus__, H01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_328}
# name 	: V_348
# particles 	: [a, W2__minus__, HP2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_553}
# name 	: V_350
# particles 	: [W2__minus__, A01, HP2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_315}
# name 	: V_352
# particles 	: [W2__minus__, H, HP2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_286}
# name 	: V_353
# particles 	: [W2__minus__, H01, HP2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_311}
# name 	: V_360
# particles 	: [W__minus__, W2__minus__, HP2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_339}
# name 	: V_366
# particles 	: [W2__minus__, W2__minus__, HP2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_572}
# name 	: V_411
# particles 	: [W2__minus__, W2__plus__, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_343}
# name 	: V_452
# particles 	: [W__minus__, W__plus__, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_343}
# name 	: V_516
# particles 	: [a, Z, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_298}
# name 	: V_522
# particles 	: [Z, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_296}
# name 	: V_528
# particles 	: [W__minus__, Z, A01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_308}
# name 	: V_529
# particles 	: [W__minus__, Z, H01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_309}
# name 	: V_530
# particles 	: [W__minus__, Z, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_316}
# name 	: V_531
# particles 	: [W__minus__, Z, HP2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_557}
# name 	: V_536
# particles 	: [W2__minus__, Z, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_288}
# name 	: V_537
# particles 	: [W2__minus__, Z, A01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_335}
# name 	: V_538
# particles 	: [W2__minus__, Z, H01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_334}
# name 	: V_539
# particles 	: [W2__minus__, Z, HP2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_353}
# name 	: V_570
# particles 	: [Z, Z, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_301}
# name 	: V_584
# particles 	: [a, Z2, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_297}
# name 	: V_590
# particles 	: [Z2, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_293}
# name 	: V_596
# particles 	: [W__minus__, Z2, A01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_319}
# name 	: V_597
# particles 	: [W__minus__, Z2, H01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_320}
# name 	: V_598
# particles 	: [W__minus__, Z2, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_322}
# name 	: V_599
# particles 	: [W__minus__, Z2, HP2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_560}
# name 	: V_604
# particles 	: [W2__minus__, Z2, H, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_289}
# name 	: V_605
# particles 	: [W2__minus__, Z2, A01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_330}
# name 	: V_606
# particles 	: [W2__minus__, Z2, H01, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_331}
# name 	: V_607
# particles 	: [W2__minus__, Z2, HP2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_552}
# name 	: V_638
# particles 	: [Z, Z2, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_303}
# name 	: V_655
# particles 	: [Z2, Z2, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_300}

# %% [markdown]
# ### Vertexes $H_{1,2}^+$ FF

# %%
vertices_HP1FF = [
    vertex for vertex in vertices_HP1 if all([lorentz.spins == [2, 2, 1] for lorentz in vertex.lorentz])
]
print(len(vertices_HP1FF), 'vertices of the type HP1FF')

vertices_HP2FF = [
    vertex for vertex in vertices_HP2 if all([lorentz.spins == [2, 2, 1] for lorentz in vertex.lorentz])
]
print(len(vertices_HP2FF), 'vertices of the type HP1FF')
# Out:
# 6 vertices of the type HP1FF
# 6 vertices of the type HP1FF

# %%
for vertex in vertices_HP1FF:
    print(vertex.particles, vertex.lorentz)
    #print(vertex.nice_string())
# Out:
# [N1, e__minus__, HP1] [FFS3]
# [N4, e__minus__, HP1] [FFS3]
# [N2, mu__minus__, HP1] [FFS3]
# [N5, mu__minus__, HP1] [FFS3]
# [N3, ta__minus__, HP1] [FFS3]
# [N6, ta__minus__, HP1] [FFS3]

# %%
for vertex in vertices_HP2FF:
    print(vertex.particles, vertex.lorentz)
    #print(vertex.nice_string())
# Out:
# [N1, e__minus__, HP2] [FFS1, FFS3]
# [N4, e__minus__, HP2] [FFS1, FFS3]
# [N2, mu__minus__, HP2] [FFS1, FFS3]
# [N5, mu__minus__, HP2] [FFS1, FFS3]
# [N3, ta__minus__, HP2] [FFS1, FFS3]
# [N6, ta__minus__, HP2] [FFS1, FFS3]

# %% [markdown]
# ## Interactions with $H_{1,2}^{++}$

# %%
vertices_HPPR = [
    vertex for vertex in vertices.all_vertices if particles.HR__plus____plus__ in vertex.particles and vertex.color == ['1']
]
print(len(vertices_HPPR), 'vertices with HPPR')

vertices_HPPL = [
    vertex for vertex in vertices.all_vertices if particles.HL__plus____plus__ in vertex.particles and vertex.color == ['1']
]
print(len(vertices_HPPL), 'vertices with HPPL')
# Out:
# 44 vertices with HPPR
# 60 vertices with HPPL

# %%
for vertex in vertices_HPPR:
    print(vertex.nice_string())
# Out:
# name 	: V_12
# particles 	: [H02, H02, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_49}
# name 	: V_13
# particles 	: [HR__minus____minus__, HR__minus____minus__, HR__plus____plus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_47}
# name 	: V_22
# particles 	: [A02, A02, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_54}
# name 	: V_23
# particles 	: [H03, H03, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_54}
# name 	: V_24
# particles 	: [HM1, HP1, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_54}
# name 	: V_25
# particles 	: [HL__minus____minus__, HL__plus____plus__, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_54}
# name 	: V_29
# particles 	: [H02, HM1, HM1, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_58}
# name 	: V_30
# particles 	: [A02, H02, HL__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_57}
# name 	: V_31
# particles 	: [H02, H03, HL__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_56}
# name 	: V_91
# particles 	: [A01, A01, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_281}
# name 	: V_92
# particles 	: [H, H, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_271}
# name 	: V_93
# particles 	: [H, H01, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_275}
# name 	: V_94
# particles 	: [H01, H01, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_281}
# name 	: V_95
# particles 	: [HM2, HP2, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSSS1]
# couplings 	: {(0, 0): GC_272}
# name 	: V_112
# particles 	: [H, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_347}
# name 	: V_113
# particles 	: [H01, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_350}
# name 	: V_127
# particles 	: [H03, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_583}
# name 	: V_129
# particles 	: [H02, HL__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_584}
# name 	: V_142
# particles 	: [H02, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_700}
# name 	: V_150
# particles 	: [HM1, HM1, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_695}
# name 	: V_151
# particles 	: [A02, HL__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_694}
# name 	: V_152
# particles 	: [H03, HL__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [SSS1]
# couplings 	: {(0, 0): GC_693}
# name 	: V_163
# particles 	: [a, a, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_130}
# name 	: V_171
# particles 	: [a, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_79}
# name 	: V_291
# particles 	: [e__minus__, e__minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [FFS1]
# couplings 	: {(0, 0): GC_628}
# name 	: V_292
# particles 	: [mu__minus__, mu__minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [FFS1]
# couplings 	: {(0, 0): GC_629}
# name 	: V_293
# particles 	: [ta__minus__, ta__minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [FFS1]
# couplings 	: {(0, 0): GC_630}
# name 	: V_338
# particles 	: [W__minus__, W__minus__, H02, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_213}
# name 	: V_341
# particles 	: [W__minus__, W__minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_699}
# name 	: V_359
# particles 	: [W__minus__, W2__minus__, H02, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_196}
# name 	: V_362
# particles 	: [W__minus__, W2__minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_697}
# name 	: V_363
# particles 	: [W2__minus__, W2__minus__, H02, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_32}
# name 	: V_368
# particles 	: [W2__minus__, W2__minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_689}
# name 	: V_388
# particles 	: [W__minus__, W2__plus__, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_191}
# name 	: V_403
# particles 	: [W2__minus__, W2__plus__, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_29}
# name 	: V_448
# particles 	: [W__minus__, W__plus__, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_210}
# name 	: V_466
# particles 	: [W2__minus__, W__plus__, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_191}
# name 	: V_511
# particles 	: [a, Z, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_147}
# name 	: V_524
# particles 	: [Z, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_127}
# name 	: V_565
# particles 	: [Z, Z, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_163}
# name 	: V_579
# particles 	: [a, Z2, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_157}
# name 	: V_592
# particles 	: [Z2, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_139}
# name 	: V_633
# particles 	: [Z, Z2, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_165}
# name 	: V_647
# particles 	: [Z2, Z2, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_167}

# %% [markdown]
# ### Vertex $H_{1,2}^{++}$ FF

# %%
vertices_HPPRFF = [
    vertex for vertex in vertices_HPPR if all([lorentz.spins == [2, 2, 1] for lorentz in vertex.lorentz])
]
print(len(vertices_HPPRFF), 'vertices of the type HPPRFF')

vertices_HPPLFF = [
    vertex for vertex in vertices_HPPL if all([lorentz.spins == [2, 2, 1] for lorentz in vertex.lorentz])
]
print(len(vertices_HPPLFF), 'vertices of the type HPPLFF')
# Out:
# 3 vertices of the type HPPRFF
# 3 vertices of the type HPPLFF

# %%
for vertex in vertices_HPPRFF:
    print(vertex.particles, vertex.lorentz)
# Out:
# [e__minus__, e__minus__, HR__plus____plus__] [FFS1]
# [mu__minus__, mu__minus__, HR__plus____plus__] [FFS1]
# [ta__minus__, ta__minus__, HR__plus____plus__] [FFS1]

# %%
for vertex in vertices_HPPLFF:
    print(vertex.particles, vertex.lorentz)
# Out:
# [e__minus__, e__minus__, HL__plus____plus__] [FFS3]
# [mu__minus__, mu__minus__, HL__plus____plus__] [FFS3]
# [ta__minus__, ta__minus__, HL__plus____plus__] [FFS3]

# %% [markdown]
# # Interactions with $W^+$, $W_2^+$

# %%
vertices_Wp = [
    vertex for vertex in vertices.all_vertices if particles.W__plus__ in vertex.particles and vertex.color == ['1']
]
print(len(vertices_Wp), 'vertices with Wp')

vertices_W2p = [
    vertex for vertex in vertices.all_vertices if particles.W2__plus__ in vertex.particles and vertex.color == ['1']
]
print(len(vertices_W2p), 'vertices with W2p')
# Out:
# 102 vertices with Wp
# 102 vertices with W2p

# %%
for vertex in vertices_Wp:
    print(vertex.nice_string())
# Out:
# name 	: V_335
# particles 	: [a, W__minus__, W__plus__]
# color 	: ['1']
# lorentz 	: [VVV1]
# couplings 	: {(0, 0): GC_240}
# name 	: V_429
# particles 	: [a, W__plus__, A02, HM1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_85}
# name 	: V_430
# particles 	: [a, W__plus__, H03, HM1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_84}
# name 	: V_431
# particles 	: [a, W__plus__, HP1, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_82}
# name 	: V_432
# particles 	: [a, W__plus__, A01, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_325}
# name 	: V_433
# particles 	: [a, W__plus__, H01, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_324}
# name 	: V_434
# particles 	: [a, W__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_327}
# name 	: V_435
# particles 	: [a, W__plus__, HM2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_561}
# name 	: V_436
# particles 	: [a, W__plus__, HM1]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_591}
# name 	: V_437
# particles 	: [W__plus__, A01, HM2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_307}
# name 	: V_438
# particles 	: [W__plus__, A02, HM1]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_10}
# name 	: V_439
# particles 	: [W__plus__, H, HM2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_312}
# name 	: V_440
# particles 	: [W__plus__, H01, HM2]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_305}
# name 	: V_441
# particles 	: [W__plus__, H03, HM1]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_9}
# name 	: V_442
# particles 	: [W__plus__, HP1, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VSS1]
# couplings 	: {(0, 0): GC_6}
# name 	: V_443
# particles 	: [W__minus__, W__plus__, A02, A02]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_29}
# name 	: V_444
# particles 	: [W__minus__, W__plus__, H03, H03]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_29}
# name 	: V_445
# particles 	: [W__minus__, W__plus__, HM1, HP1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_30}
# name 	: V_446
# particles 	: [W__minus__, W__plus__, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_29}
# name 	: V_447
# particles 	: [W__minus__, W__plus__, H02, H02]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_210}
# name 	: V_448
# particles 	: [W__minus__, W__plus__, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_210}
# name 	: V_449
# particles 	: [W__minus__, W__plus__, A01, A01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_345}
# name 	: V_450
# particles 	: [W__minus__, W__plus__, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_345}
# name 	: V_451
# particles 	: [W__minus__, W__plus__, H01, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_344}
# name 	: V_452
# particles 	: [W__minus__, W__plus__, HM2, HP2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_343}
# name 	: V_453
# particles 	: [W__minus__, W__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_317}
# name 	: V_454
# particles 	: [W__minus__, W__plus__, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_566}
# name 	: V_455
# particles 	: [W__minus__, W__plus__, H01]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_558}
# name 	: V_456
# particles 	: [W__minus__, W__plus__, H03]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_578}
# name 	: V_457
# particles 	: [W__minus__, W__plus__, H02]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_698}
# name 	: V_458
# particles 	: [a, a, W__minus__, W__plus__]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_243}
# name 	: V_459
# particles 	: [W__minus__, W__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVV1]
# couplings 	: {(0, 0): GC_245}
# name 	: V_460
# particles 	: [W__minus__, W__plus__, Z2]
# color 	: ['1']
# lorentz 	: [VVV1]
# couplings 	: {(0, 0): GC_244}
# name 	: V_461
# particles 	: [W2__minus__, W__plus__, A02, A02]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_192}
# name 	: V_462
# particles 	: [W2__minus__, W__plus__, H02, H02]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_191}
# name 	: V_463
# particles 	: [W2__minus__, W__plus__, H03, H03]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_192}
# name 	: V_464
# particles 	: [W2__minus__, W__plus__, HM1, HP1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_193}
# name 	: V_465
# particles 	: [W2__minus__, W__plus__, HL__minus____minus__, HL__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_192}
# name 	: V_466
# particles 	: [W2__minus__, W__plus__, HR__minus____minus__, HR__plus____plus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_191}
# name 	: V_467
# particles 	: [W2__minus__, W__plus__, A01, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_346}
# name 	: V_468
# particles 	: [W2__minus__, W__plus__, H, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_342}
# name 	: V_469
# particles 	: [W2__minus__, W__plus__, A01, A01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_338}
# name 	: V_470
# particles 	: [W2__minus__, W__plus__, H, H]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_338}
# name 	: V_471
# particles 	: [W2__minus__, W__plus__, A01, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_340}
# name 	: V_472
# particles 	: [W2__minus__, W__plus__, H01, H01]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_337}
# name 	: V_473
# particles 	: [W2__minus__, W__plus__, A01]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_567}
# name 	: V_474
# particles 	: [W2__minus__, W__plus__, H01]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_564}
# name 	: V_475
# particles 	: [W2__minus__, W__plus__, H]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_562}
# name 	: V_476
# particles 	: [W2__minus__, W__plus__, H03]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_585}
# name 	: V_477
# particles 	: [W2__minus__, W__plus__, H02]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_696}
# name 	: V_478
# particles 	: [W2__minus__, W__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVV1]
# couplings 	: {(0, 0): GC_221}
# name 	: V_479
# particles 	: [W2__minus__, W__plus__, Z2]
# color 	: ['1']
# lorentz 	: [VVV1]
# couplings 	: {(0, 0): GC_216}
# name 	: V_480
# particles 	: [W2__plus__, W__plus__, A02, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_194}
# name 	: V_481
# particles 	: [W2__plus__, W__plus__, H03, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_195}
# name 	: V_482
# particles 	: [W2__plus__, W__plus__, H02, HR__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_196}
# name 	: V_483
# particles 	: [W2__plus__, W__plus__, HM2, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_339}
# name 	: V_484
# particles 	: [W2__plus__, W__plus__, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_586}
# name 	: V_485
# particles 	: [W2__plus__, W__plus__, HR__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_697}
# name 	: V_486
# particles 	: [W__minus__, W__minus__, W2__plus__, W__plus__]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_252}
# name 	: V_487
# particles 	: [W__minus__, W2__minus__, W2__plus__, W__plus__]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_215}
# name 	: V_488
# particles 	: [W2__minus__, W2__minus__, W2__plus__, W__plus__]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_251}
# name 	: V_489
# particles 	: [W__plus__, W__plus__, A02, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_31}
# name 	: V_490
# particles 	: [W__plus__, W__plus__, H03, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_32}
# name 	: V_491
# particles 	: [W__plus__, W__plus__, H02, HR__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_213}
# name 	: V_492
# particles 	: [W__plus__, W__plus__, HM2, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_573}
# name 	: V_493
# particles 	: [W__plus__, W__plus__, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_579}
# name 	: V_494
# particles 	: [W__plus__, W__plus__, HR__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_699}
# name 	: V_495
# particles 	: [W__minus__, W__minus__, W__plus__, W__plus__]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_253}
# name 	: V_496
# particles 	: [W__minus__, W2__minus__, W__plus__, W__plus__]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_252}
# name 	: V_497
# particles 	: [W2__minus__, W2__minus__, W__plus__, W__plus__]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_215}
# name 	: V_551
# particles 	: [W__plus__, Z, A02, HM1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_132}
# name 	: V_552
# particles 	: [W__plus__, Z, H03, HM1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_133}
# name 	: V_553
# particles 	: [W__plus__, Z, HP1, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_131}
# name 	: V_554
# particles 	: [W__plus__, Z, A01, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_310}
# name 	: V_555
# particles 	: [W__plus__, Z, H01, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_309}
# name 	: V_556
# particles 	: [W__plus__, Z, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_316}
# name 	: V_557
# particles 	: [W__plus__, Z, HM2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_557}
# name 	: V_558
# particles 	: [W__plus__, Z, HM1]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_593}
# name 	: V_559
# particles 	: [a, W__minus__, W__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVVV5]
# couplings 	: {(0, 0): GC_247}
# name 	: V_560
# particles 	: [a, W2__minus__, W__plus__, Z]
# color 	: ['1']
# lorentz 	: [VVVV5]
# couplings 	: {(0, 0): GC_231}
# name 	: V_576
# particles 	: [W__minus__, W__plus__, Z, Z]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_249}
# name 	: V_577
# particles 	: [W2__minus__, W__plus__, Z, Z]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_232}
# name 	: V_619
# particles 	: [W__plus__, Z2, A02, HM1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_142}
# name 	: V_620
# particles 	: [W__plus__, Z2, H03, HM1]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_143}
# name 	: V_621
# particles 	: [W__plus__, Z2, HP1, HL__minus____minus__]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_141}
# name 	: V_622
# particles 	: [W__plus__, Z2, A01, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_321}
# name 	: V_623
# particles 	: [W__plus__, Z2, H01, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_320}
# name 	: V_624
# particles 	: [W__plus__, Z2, H, HM2]
# color 	: ['1']
# lorentz 	: [VVSS1]
# couplings 	: {(0, 0): GC_322}
# name 	: V_625
# particles 	: [W__plus__, Z2, HM2]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_560}
# name 	: V_626
# particles 	: [W__plus__, Z2, HM1]
# color 	: ['1']
# lorentz 	: [VVS1]
# couplings 	: {(0, 0): GC_594}
# name 	: V_627
# particles 	: [a, W__minus__, W__plus__, Z2]
# color 	: ['1']
# lorentz 	: [VVVV5]
# couplings 	: {(0, 0): GC_246}
# name 	: V_628
# particles 	: [a, W2__minus__, W__plus__, Z2]
# color 	: ['1']
# lorentz 	: [VVVV5]
# couplings 	: {(0, 0): GC_226}
# name 	: V_644
# particles 	: [W__minus__, W__plus__, Z, Z2]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_250}
# name 	: V_645
# particles 	: [W2__minus__, W__plus__, Z, Z2]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_234}
# name 	: V_661
# particles 	: [W__minus__, W__plus__, Z2, Z2]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_248}
# name 	: V_662
# particles 	: [W2__minus__, W__plus__, Z2, Z2]
# color 	: ['1']
# lorentz 	: [VVVV2]
# couplings 	: {(0, 0): GC_233}
# name 	: V_702
# particles 	: [N1, e__minus__, W__plus__]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_34, (0, 1): GC_204}
# name 	: V_703
# particles 	: [N4, e__minus__, W__plus__]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_37, (0, 1): GC_207}
# name 	: V_704
# particles 	: [N2, mu__minus__, W__plus__]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_35, (0, 1): GC_205}
# name 	: V_705
# particles 	: [N5, mu__minus__, W__plus__]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_38, (0, 1): GC_208}
# name 	: V_706
# particles 	: [N3, ta__minus__, W__plus__]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_36, (0, 1): GC_206}
# name 	: V_707
# particles 	: [N6, ta__minus__, W__plus__]
# color 	: ['1']
# lorentz 	: [FFV2, FFV3]
# couplings 	: {(0, 0): GC_39, (0, 1): GC_209}

# %% [markdown]
# ## Vertex $W^+$ FF

# %%
vertices_WFF = [
    vertex for vertex in vertices_Wp if all([lorentz.spins == [2, 2, 3] for lorentz in vertex.lorentz])
]
print(len(vertices_WFF), 'vertices of the type WFF')

vertices_W2FF = [
    vertex for vertex in vertices_W2p if all([lorentz.spins == [2, 2, 3] for lorentz in vertex.lorentz])
]
print(len(vertices_W2FF), 'vertices of the type W2FF')
# Out:
# 6 vertices of the type WFF
# 6 vertices of the type W2FF

# %%
for vertex in vertices_WFF:
    print(vertex.particles, vertex.lorentz)
# Out:
# [N1, e__minus__, W__plus__] [FFV2, FFV3]
# [N4, e__minus__, W__plus__] [FFV2, FFV3]
# [N2, mu__minus__, W__plus__] [FFV2, FFV3]
# [N5, mu__minus__, W__plus__] [FFV2, FFV3]
# [N3, ta__minus__, W__plus__] [FFV2, FFV3]
# [N6, ta__minus__, W__plus__] [FFV2, FFV3]

# %%
for vertex in vertices_W2FF:
    print(vertex.particles, vertex.lorentz)
# Out:
# [N1, e__minus__, W2__plus__] [FFV2, FFV3]
# [N4, e__minus__, W2__plus__] [FFV2, FFV3]
# [N2, mu__minus__, W2__plus__] [FFV2, FFV3]
# [N5, mu__minus__, W2__plus__] [FFV2, FFV3]
# [N3, ta__minus__, W2__plus__] [FFV2, FFV3]
# [N6, ta__minus__, W2__plus__] [FFV2, FFV3]
